# %% [markdown]
# <a href="https://colab.research.google.com/github/blindauth/abstention_experiments/blob/master/abstention_experiments/diabetic_retinopathy/RunDiabeticRetinopathyExperiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -r abstention
# !pip uninstall abstention
# !git clone https://github.com/blindauth/abstention.git
# !pip install abstention/
![[ -e abstention_experiments ]] || git clone https://github.com/blindauth/abstention_experiments.git
# Out:
# Uninstalling abstention-0.1.2.1:
#   Would remove:
#     /usr/local/lib/python3.6/dist-packages/abstention-0.1.2.1.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/abstention/*
# Proceed (y/n)? y
#   Successfully uninstalled abstention-0.1.2.1
# Cloning into 'abstention'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 51 (delta 18), reused 42 (delta 9), pack-reused 0
# Unpacking objects: 100% (51/51), done.
# Processing ./abstention
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.6/dist-packages (from abstention==0.1.2.1) (1.16.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.6/dist-packages (from abstention==0.1.2.1) (0.20.3)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from abstention==0.1.2.1) (1.2.1)
# Building wheels for collected packages: abstention
#   Building wheel for abstention (setup.py) ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dmeowolv/wheels/60/8e/d2/9e9ca02e7b5f76bfda2e2daa6dcbe42c19095c502ccb653729
# Successfully built abstention
# Installing collected packages: abstention
# Successfully installed abstention-0.1.2.1

# %%
# !ls abstention_experiments/diabetic_retinopathy
# Out:
# flip-False_rotamt-0    flip-False_rotamt-90  flip-True_rotamt-270
# flip-False_rotamt-180  flip-True_rotamt-0    flip-True_rotamt-90
# flip-False_rotamt-270  flip-True_rotamt-180  valid_labels.txt.gz

# %%
import numpy as np
import gzip
from sklearn.preprocessing import LabelBinarizer

#The model used was the one made available at
# https://github.com/JeffreyDF/kaggle_diabetic_retinopathy
# It was the fifth-place winner of the kaggle DR competition
#Because this was a kaggle competition, we don't have access to the test-set
# labels, thus we are going to split the validation set that was used to
# train this publicly-available model into a 'pseudo test set' and a 
# 'pseudo validation set'.
orig_valid_labels = LabelBinarizer().fit_transform(
    np.array([float(x.decode("utf-8").split("\t")[1])
              for x in gzip.open("abstention_experiments/diabetic_retinopathy/valid_labels.txt.gz",'rb')]))

#num_folds is the number of folds we are going to use to split the data
# into a 'pseudo test' and 'pseudo validation' set
num_folds = 30

# %%
#Each 'parent folder' stores the predictions of the model under different
# input data transformations (flip or rotation). We do this facilititate
# data augmentation, which is helpful when we simulate distribution shift
parent_folders = ["flip-False_rotamt-0",
                  "flip-True_rotamt-0",
                  "flip-False_rotamt-90",
                  "flip-True_rotamt-90",
                  "flip-False_rotamt-180",
                  "flip-True_rotamt-180",
                  "flip-False_rotamt-270",
                  "flip-True_rotamt-270"]

#read in the predictions for the different transformations, both deterministic
# and with test-time dtropout enabled
parent_folder_to_det_pred = {}
for parent_folder in parent_folders:
    det_preds = np.array([
            [float(y) for y in x.decode("utf-8").split("\t")[1:]]
             for x in gzip.open("abstention_experiments/diabetic_retinopathy/"
                          +parent_folder+"/deterministic_preds.txt.gz", 'rb')])
    parent_folder_to_det_pred[parent_folder] = det_preds
    
parent_folder_to_nondet_pred = {}
parent_folder_to_mean_nondet_pred = {}
for parent_folder in parent_folders:
    nondet_preds = []
    for i in range(100):
        single_nondet_pred = np.array([
            [float(y) for y in x.decode("utf-8").split("\t")[1:]]
             for x in gzip.open("abstention_experiments/diabetic_retinopathy/"
              +parent_folder+"/nondeterministic_preds_"+str(i)+".txt.gz", 'rb')])
        nondet_preds.append(single_nondet_pred)
    nondet_preds = np.array(nondet_preds)
    parent_folder_to_nondet_pred[parent_folder] = nondet_preds
    #Also take the mean of the test-time dropout runs so that we can compare
    # the results of weight rescaling to the results of monte-carlo dropout
    parent_folder_to_mean_nondet_pred[parent_folder] = np.mean(nondet_preds,axis=0)

# %%
import abstention
from abstention.calibration import (compute_ece, compute_ece_with_bins,
                                    TempScaling)
from abstention.label_shift import EMImbalanceAdapter
from abstention.abstention import (
    weighted_kappa_metric, EstMarginalWeightedKappa, DistMaxClassProbFromOne,
    Entropy, Uncertainty, OneMinusJSDivFromClassFreq)
from collections import OrderedDict
import numpy as np
import sys
import json
import os


def inverse_softmax(preds):
    return np.log(preds) - np.mean(np.log(preds),axis=1)[:,None]

quadratic_weights = np.array([[(i-j)**2 for i in range(5)]
                               for j in range(5)])

#When a test-set distribution shift is simulated, these are the factors
# by which different classes will be relatively upsampled.
imbalance_upsampling=[1, 2, 5, 8, 8]

abstname_to_factory = OrderedDict([
    ("estmarginalweightedkappa",
     EstMarginalWeightedKappa(weights=quadratic_weights,
                      verbose=False, mode='argmax')),
    ("jsdiv", OneMinusJSDivFromClassFreq()),
    ("distmaxclassprobfromone", DistMaxClassProbFromOne()),
    ("entropy", Entropy()),
    ("variance", Uncertainty())
])


imbalanceadapterfactory = EMImbalanceAdapter(verbose=False)

abstfracs = [0.15, 0.30]

for useweightrescalepreds in [True, False]:
  
  if (useweightrescalepreds == True):
    preds_lookup = parent_folder_to_det_pred
  else:
    preds_lookup = parent_folder_to_mean_nondet_pred
  ttdsamples_lookup = parent_folder_to_nondet_pred
  
  for labelshift in [True, False]:
    
    if (labelshift==True):
      #if labelshift is True, need to use bias-corrected temperature
      # scaling to get rid of bias in the calibration that can compromise
      # label shift adaptation
      calibfactory = TempScaling(ece_bins=15, verbose=False,
                           bias_positions=[0,1,2,3,4])
    else:
      #otherwise, use regular temperature scaling.
      calibfactory = TempScaling(ece_bins=15, verbose=False)
    
    print("\nuseweightrescalepreds", useweightrescalepreds)
    print("labelshift", labelshift)
    
    methodprefix_to_baseperfs = OrderedDict()
    if (labelshift==False):
      methodprefix_to_baseperfs["yescalib"] = []
      methodprefix_to_baseperfs["nocalib"] = []
    else:
      methodprefix_to_baseperfs["yesadapt"] = []
      methodprefix_to_baseperfs["noadapt"] = []
    
    abstfrac_to_methodname_to_perfs = OrderedDict()
    for abstfrac in abstfracs:
      methodname_to_perfs = OrderedDict()
      for abstname in abstname_to_factory:
        if (labelshift==False):
          methodname_to_perfs["yescalib:"+abstname] = []
          methodname_to_perfs["nocalib:"+abstname] = []
        else:
          methodname_to_perfs["yesadapt:"+abstname] = []
          methodname_to_perfs["noadapt:"+abstname] = []
      abstfrac_to_methodname_to_perfs[abstfrac] = methodname_to_perfs
    
    for fold_number in range(num_folds):
      
      print("\non fold",fold_number)

      rng = np.random.RandomState(fold_number*1000)

      #to avoid contamination between the validation and test sets, we will
      # do the split according to patient ids.
      #the data is in pairs of (left eye, right eye) per patient (entry for
      # the right eye comes after the entry for the left eye); hence, the number of
      # unique patients is 0.5*len(valid_labels)
      patient_id_ordering = list(range(int(0.5*len(orig_valid_labels))))
      rng.shuffle(patient_id_ordering) #shuffle the patient id order

      #prepare the valid-test split, with an imbalance shift if appropriate
      pseudovalid_uncalib_preds = []
      pseudotest_uncalib_preds = []
      pseudovalid_uncalib_ttdsamples = [] #ttd = test-time dropout
      pseudotest_uncalib_ttdsamples = []
      pseudovalid_labels = []
      pseudotest_labels = []
      pseudovalid_label_counts = np.zeros(5)
      pseudotest_label_counts = np.zeros(5)
      for i in patient_id_ordering:
        left_eye_label = orig_valid_labels[2*i]
        right_eye_label = orig_valid_labels[(2*i)+1]
        most_diseased_label = max(np.argmax(left_eye_label),
                                  np.argmax(right_eye_label))
        #If labelshift=False, strive for roughly equal representation
        # of all classes. If imbalanceshift=True, we will modify the
        # distributions in a later step
        if (pseudovalid_label_counts[most_diseased_label] <
          pseudotest_label_counts[most_diseased_label]):
          in_test = False #append these examples to the validation set
          appendto_uncalib_preds = pseudovalid_uncalib_preds
          appendto_uncalib_ttdsamples = pseudovalid_uncalib_ttdsamples
          appendto_labels = pseudovalid_labels
          appendto_label_counts = pseudovalid_label_counts
        else:
          in_test = True #append these examples to the test set
          appendto_uncalib_preds = pseudotest_uncalib_preds
          appendto_uncalib_ttdsamples = pseudotest_uncalib_ttdsamples
          appendto_labels = pseudotest_labels
          appendto_label_counts = pseudotest_label_counts

        #increment by label counts for left and right eye
        appendto_label_counts += orig_valid_labels[2*i]
        appendto_label_counts += orig_valid_labels[(2*i)+1]
        #iterate through all the augmentation splits
        for parent_folder_idx,parent_folder in enumerate(parent_folders):
          #we include a particular augmentation split if:
          # (1) we are in the validation set, OR
          # (2) labelshift=False, OR
          # (3) labelshift=True, AND imbalance_upsampling for the example's
          #     class is greater than the parent folder idx.
          #Left eye:
          if ((in_test==False) or (labelshift==False) or
              imbalance_upsampling[
               np.argmax(orig_valid_labels[2*i])] > parent_folder_idx):
              appendto_labels.append(orig_valid_labels[2*i])
              appendto_uncalib_preds.append(
                      preds_lookup[parent_folder][2*i])
              appendto_uncalib_ttdsamples.append(
                  ttdsamples_lookup[parent_folder][:,(2*i)])                  
          #Right eye:
          if ((in_test==False) or (labelshift==False) or
              imbalance_upsampling[
                  np.argmax(orig_valid_labels[(2*i) + 1])] > parent_folder_idx): 
              appendto_labels.append(orig_valid_labels[(2*i)+1])
              appendto_uncalib_preds.append(
                  preds_lookup[parent_folder][(2*i)+1])
              appendto_uncalib_ttdsamples.append(
                  ttdsamples_lookup[parent_folder][:,(2*i)+1])

      #cast things to np arrays, infer softmax logits where needed
      # (logits are used during calibration)
      pseudovalid_uncalib_preds = np.array(pseudovalid_uncalib_preds)
      pseudotest_uncalib_preds = np.array(pseudotest_uncalib_preds)
      pseudovalid_uncalib_pred_logits = inverse_softmax(pseudovalid_uncalib_preds)
      pseudotest_uncalib_pred_logits = inverse_softmax(pseudotest_uncalib_preds)
      pseudovalid_uncalib_ttdsamples = np.array(
          pseudovalid_uncalib_ttdsamples).transpose((1,0,2))
      pseudotest_uncalib_ttdsamples = np.array(
          pseudotest_uncalib_ttdsamples).transpose((1,0,2))
      pseudovalid_uncalib_ttdsamples_logits = np.array([
              inverse_softmax(x) for x in pseudovalid_uncalib_ttdsamples])        
      pseudotest_uncalib_ttdsamples_logits = np.array([
              inverse_softmax(x) for x in pseudotest_uncalib_ttdsamples])
      pseudovalid_labels = np.array(pseudovalid_labels) 
      pseudotest_labels = np.array(pseudotest_labels)

      #Apply calibration
      the_calibrator = calibfactory(
                          valid_preacts=pseudovalid_uncalib_pred_logits,
                          valid_labels=pseudovalid_labels)
      pseudovalid_calib_preds = the_calibrator(pseudovalid_uncalib_pred_logits)
      pseudotest_calib_preds = the_calibrator(pseudotest_uncalib_pred_logits)   
      pseudotest_calib_ttdsamples = np.array(
          [the_calibrator(x) for x in pseudotest_uncalib_ttdsamples_logits])

      #Apply labelshift adaptation to the calibrated preds, if applicable
      if (labelshift==True):
        imbalance_adaptation_func = imbalanceadapterfactory(
            valid_labels=None,
            tofit_initial_posterior_probs=pseudotest_calib_preds,
            valid_posterior_probs=pseudovalid_calib_preds)
        pseudotest_adapted_preds = imbalance_adaptation_func(
            pseudotest_calib_preds)
        pseudotest_adapted_ttdsamples = np.array([
                      imbalance_adaptation_func(x) for
                      x in pseudotest_calib_ttdsamples])

      if (labelshift==False):
        methodprefix_and_valstouse = [
            ('yescalib', pseudotest_calib_preds, pseudotest_calib_ttdsamples),
            ('nocalib', pseudotest_uncalib_preds, pseudotest_uncalib_ttdsamples),
        ]
      else:
        methodprefix_and_valstouse = [
            ('yesadapt', pseudotest_adapted_preds, pseudotest_adapted_ttdsamples),
            ('noadapt', pseudotest_calib_preds, pseudotest_calib_ttdsamples),
        ]

      for (methodprefix, pseudotest_preds_to_use,
           pseudotest_ttdsamples_to_use) in methodprefix_and_valstouse:

        #compute the pre-abstention perf
        base_weighted_kappa = weighted_kappa_metric(
                predprobs=pseudotest_preds_to_use,
                true_labels=pseudotest_labels,
                weights=quadratic_weights,
                mode='argmax')
        methodprefix_to_baseperfs[methodprefix].append(base_weighted_kappa)
        
        print("\n"+methodprefix,"base perf", base_weighted_kappa)

        #take the variance in the most confident class, as described in
        # https://arxiv.org/pdf/1705.08500.pdf
        pseudotest_ttdsamples_var =\
          np.var(pseudotest_ttdsamples_to_use, axis=0)[
           list(range(pseudotest_ttdsamples_to_use.shape[1])),
           np.argmax(np.mean(pseudotest_ttdsamples_to_use, axis=0),axis=-1)]
        #Iterate over abstention methods
        for abstname in abstname_to_factory:
          abstfunc = abstname_to_factory[abstname](
                      valid_labels=None, valid_posterior=None)
          abstpriorities = abstfunc(posterior_probs=pseudotest_preds_to_use,
                                    uncertainties=pseudotest_ttdsamples_var)
          sortedabstindices = np.array([
              x[0] for x in sorted(enumerate(abstpriorities),
                                   key=lambda x: x[1])])
          #Iterate over abstention levels
          for abstfrac in abstfracs:
            indices_to_retain =\
              sortedabstindices[:int(len(sortedabstindices )*(1-abstfrac))]
            retained_pseudotest_preds = np.array([
                pseudotest_preds_to_use[i] for i in indices_to_retain])
            retained_pseudotest_labels = np.array([
                pseudotest_labels[i] for i in indices_to_retain])
            #Compute performance
            postabst_weighted_kappa = weighted_kappa_metric(
                predprobs=retained_pseudotest_preds,
                true_labels=retained_pseudotest_labels,
                weights=quadratic_weights,
                mode='argmax')
            abstfrac_to_methodname_to_perfs[abstfrac][
                methodprefix+":"+abstname].append(postabst_weighted_kappa)
            print("abstfrac",abstfrac,
                  abstname,"perf",postabst_weighted_kappa)
    
    file_out = (
        "diabeticretinopathy_useweightrescalpreds-"+str(useweightrescalepreds)
        +"_labelshift-"+str(labelshift)+"_abstention_results.json")
    dict_to_write = {
        "methodprefix_to_baseperfs": methodprefix_to_baseperfs,
        "abstfrac_to_methodname_to_perfs": abstfrac_to_methodname_to_perfs}
    open(file_out, 'w').write(
        json.dumps(dict_to_write,
                   sort_keys=True, indent=4, separators=(',', ': ')))
    os.system("gzip -f "+file_out)
# Out:
# useweightrescalepreds True
# labelshift True
#
# on fold 0
#
# yesadapt base perf 0.7754512877213324
# abstfrac 0.15 estmarginalweightedkappa perf 0.8324768888107463
# abstfrac 0.3 estmarginalweightedkappa perf 0.8537599471919868
# abstfrac 0.15 jsdiv perf 0.8347235392239909
# abstfrac 0.3 jsdiv perf 0.8403852847447665
# abstfrac 0.15 distmaxclassprobfromone perf 0.8052640243357561
# abstfrac 0.3 distmaxclassprobfromone perf 0.8347340755396746
# abstfrac 0.15 entropy perf 0.8158252986087732
# abstfrac 0.3 entropy perf 0.8506095772251889
# abstfrac 0.15 variance perf 0.7722051019463386
# abstfrac 0.3 variance perf 0.7975799297885889
#
# noadapt base perf 0.7170236582198334
# abstfrac 0.15 estmarginalweightedkappa perf 0.7906293630157774
# abstfrac 0.3 estmarginalweightedkappa perf 0.8221966093192521
# abstfrac 0.15 jsdiv perf 0.8159231695944269
# abstfrac 0.3 jsdiv perf 0.8420341533130891
# abstfrac 0.15 distmaxclassprobfromone perf 0.7475502648034935
# abstfrac 0.3 distmaxclassprobfromone perf 0.7710964288192184
# abstfrac 0.15 entropy perf 0.7561364190968785
# abstfrac 0.3 entropy perf 0.7793809533187465
# abstfrac 0.15 variance perf 0.7174372434288709
# abstfrac 0.3 variance perf 0.737260627931023
#
# on fold 1
#
# yesadapt base perf 0.8049372852803363
# abstfrac 0.15 estmarginalweightedkappa perf 0.846406490409221
# abstfrac 0.3 estmarginalweightedkappa perf 0.8718721660648684
# abstfrac 0.15 jsdiv perf 0.8499387168245887
# abstfrac 0.3 jsdiv perf 0.8564594340966663
# abstfrac 0.15 distmaxclassprobfromone perf 0.8396926124260368
# abstfrac 0.3 distmaxclassprobfromone perf 0.8566103932008551
# abstfrac 0.15 entropy perf 0.8378466603224265
# abstfrac 0.3 entropy perf 0.8640140383421309
# abstfrac 0.15 variance perf 0.784567547555918
# abstfrac 0.3 variance perf 0.789075379582298
#
# noadapt base perf 0.7389888944121881
# abstfrac 0.15 estmarginalweightedkappa perf 0.7971829743198507
# abstfrac 0.3 estmarginalweightedkappa perf 0.822044464668559
# abstfrac 0.15 jsdiv perf 0.8208719930851562
# abstfrac 0.3 jsdiv perf 0.8518857468894647
# abstfrac 0.15 distmaxclassprobfromone perf 0.762340671743773
# abstfrac 0.3 distmaxclassprobfromone perf 0.7845241202465413
# abstfrac 0.15 entropy perf 0.7672960571501927
# abstfrac 0.3 entropy perf 0.7862852285983852
# abstfrac 0.15 variance perf 0.7380912642327297
# abstfrac 0.3 variance perf 0.755580723883326
#
# on fold 2
#
# yesadapt base perf 0.8097238920617178
# abstfrac 0.15 estmarginalweightedkappa perf 0.8513142152414996
# abstfrac 0.3 estmarginalweightedkappa perf 0.8611625022902625
# abstfrac 0.15 jsdiv perf 0.8473772408998077
# abstfrac 0.3 jsdiv perf 0.8435936038780457
# abstfrac 0.15 distmaxclassprobfromone perf 0.8342070999897375
# abstfrac 0.3 distmaxclassprobfromone perf 0.8493262891216794
# abstfrac 0.15 entropy perf 0.8436597692005978
# abstfrac 0.3 entropy perf 0.8654933119848982
# abstfrac 0.15 variance perf 0.8087779363531784
# abstfrac 0.3 variance perf 0.8139805880329514
#
# noadapt base perf 0.7724219107407165
# abstfrac 0.15 estmarginalweightedkappa perf 0.8282660649324091
# abstfrac 0.3 estmarginalweightedkappa perf 0.846772029192257
# abstfrac 0.15 jsdiv perf 0.8416137408902673
# abstfrac 0.3 jsdiv perf 0.8602211863324161
# abstfrac 0.15 distmaxclassprobfromone perf 0.7999568483717697
# abstfrac 0.3 distmaxclassprobfromone perf 0.8179727284062799
# abstfrac 0.15 entropy perf 0.8085137676713169
# abstfrac 0.3 entropy perf 0.8256341134783073
# abstfrac 0.15 variance perf 0.7748631594570016
# abstfrac 0.3 variance perf 0.7980475047171878
#
# on fold 3
#
# yesadapt base perf 0.8097229234506993
# abstfrac 0.15 estmarginalweightedkappa perf 0.8578032702142109
# abstfrac 0.3 estmarginalweightedkappa perf 0.8782783985655923
# abstfrac 0.15 jsdiv perf 0.8567988441364901
# abstfrac 0.3 jsdiv perf 0.8599573996635672
# abstfrac 0.15 distmaxclassprobfromone perf 0.8456014066412997
# abstfrac 0.3 distmaxclassprobfromone perf 0.8746682506329011
# abstfrac 0.15 entropy perf 0.8530566757451338
# abstfrac 0.3 entropy perf 0.8714221493715208
# abstfrac 0.15 variance perf 0.8130844909456965
# abstfrac 0.3 variance perf 0.8381874920853051
#
# noadapt base perf 0.7540581037922442
# abstfrac 0.15 estmarginalweightedkappa perf 0.8182304500221431
# abstfrac 0.3 estmarginalweightedkappa perf 0.8457178564402837
# abstfrac 0.15 jsdiv perf 0.8408788227142914
# abstfrac 0.3 jsdiv perf 0.8780409993188248
# abstfrac 0.15 distmaxclassprobfromone perf 0.7874627693622093
# abstfrac 0.3 distmaxclassprobfromone perf 0.8084104005565307
# abstfrac 0.15 entropy perf 0.7961553308516747
# abstfrac 0.3 entropy perf 0.8089687297199953
# abstfrac 0.15 variance perf 0.7534039524955027
# abstfrac 0.3 variance perf 0.7806601936752934
#
# on fold 4
#
# yesadapt base perf 0.7612494649107345
# abstfrac 0.15 estmarginalweightedkappa perf 0.8085177340606099
# abstfrac 0.3 estmarginalweightedkappa perf 0.8422335324490222
# abstfrac 0.15 jsdiv perf 0.8194493356927186
# abstfrac 0.3 jsdiv perf 0.8288360921292659
# abstfrac 0.15 distmaxclassprobfromone perf 0.7972491449929171
# abstfrac 0.3 distmaxclassprobfromone perf 0.8316374520897654
# abstfrac 0.15 entropy perf 0.804155042799705
# abstfrac 0.3 entropy perf 0.8374964931933512
# abstfrac 0.15 variance perf 0.7626755570729365
# abstfrac 0.3 variance perf 0.7956654425076295
#
# noadapt base perf 0.7358339130559411
# abstfrac 0.15 estmarginalweightedkappa perf 0.7839093016121268
# abstfrac 0.3 estmarginalweightedkappa perf 0.8101636686330818
# abstfrac 0.15 jsdiv perf 0.8061332954860165
# abstfrac 0.3 jsdiv perf 0.8387516198103699
# abstfrac 0.15 distmaxclassprobfromone perf 0.7582625832923177
# abstfrac 0.3 distmaxclassprobfromone perf 0.7776989529240939
# abstfrac 0.15 entropy perf 0.7626674430678418
# abstfrac 0.3 entropy perf 0.7839396263779934
# abstfrac 0.15 variance perf 0.7327897541231965
# abstfrac 0.3 variance perf 0.7450915738388484
#
# on fold 5
#
# yesadapt base perf 0.7367751940806753
# abstfrac 0.15 estmarginalweightedkappa perf 0.801132193372138
# abstfrac 0.3 estmarginalweightedkappa perf 0.8321981194210638
# abstfrac 0.15 jsdiv perf 0.8009328845653443
# abstfrac 0.3 jsdiv perf 0.8201324309510898
# abstfrac 0.15 distmaxclassprobfromone perf 0.7547175831615809
# abstfrac 0.3 distmaxclassprobfromone perf 0.7605679987212781
# abstfrac 0.15 entropy perf 0.7751718025609065
# abstfrac 0.3 entropy perf 0.7846500172648362
# abstfrac 0.15 variance perf 0.7181451555643913
# abstfrac 0.3 variance perf 0.7314656253186573
#
# noadapt base perf 0.6963240254981244
# abstfrac 0.15 estmarginalweightedkappa perf 0.7593903081116746
# abstfrac 0.3 estmarginalweightedkappa perf 0.7820612978394378
# abstfrac 0.15 jsdiv perf 0.7815120455396591
# abstfrac 0.3 jsdiv perf 0.8152857472154046
# abstfrac 0.15 distmaxclassprobfromone perf 0.7102367756370067
# abstfrac 0.3 distmaxclassprobfromone perf 0.6965001988516766
# abstfrac 0.15 entropy perf 0.7152526088777036
# abstfrac 0.3 entropy perf 0.7055554374125128
# abstfrac 0.15 variance perf 0.6798815012886842
# abstfrac 0.3 variance perf 0.6782841393700163
#
# on fold 6
#
# yesadapt base perf 0.7936353869604363
# abstfrac 0.15 estmarginalweightedkappa perf 0.8306413466086736
# abstfrac 0.3 estmarginalweightedkappa perf 0.8496848583872019
# abstfrac 0.15 jsdiv perf 0.832863730725956
# abstfrac 0.3 jsdiv perf 0.8370812597876522
# abstfrac 0.15 distmaxclassprobfromone perf 0.8195823864364287
# abstfrac 0.3 distmaxclassprobfromone perf 0.8437911673460048
# abstfrac 0.15 entropy perf 0.8301874378017386
# abstfrac 0.3 entropy perf 0.8472480079784765
# abstfrac 0.15 variance perf 0.7949391518790543
# abstfrac 0.3 variance perf 0.7954406196483841
#
# noadapt base perf 0.7303464520804003
# abstfrac 0.15 estmarginalweightedkappa perf 0.7964546211309078
# abstfrac 0.3 estmarginalweightedkappa perf 0.8212431522096827
# abstfrac 0.15 jsdiv perf 0.8214502636324175
# abstfrac 0.3 jsdiv perf 0.8520390438904419
# abstfrac 0.15 distmaxclassprobfromone perf 0.7596910978199012
# abstfrac 0.3 distmaxclassprobfromone perf 0.7852275659022961
# abstfrac 0.15 entropy perf 0.7676848586728009
# abstfrac 0.3 entropy perf 0.7827643187952467
# abstfrac 0.15 variance perf 0.7253631621649004
# abstfrac 0.3 variance perf 0.7463487521080924
#
# on fold 7
#
# yesadapt base perf 0.7644327293192079
# abstfrac 0.15 estmarginalweightedkappa perf 0.8287991840967596
# abstfrac 0.3 estmarginalweightedkappa perf 0.8655780878232081
# abstfrac 0.15 jsdiv perf 0.8293795642032078
# abstfrac 0.3 jsdiv perf 0.8520967317611499
# abstfrac 0.15 distmaxclassprobfromone perf 0.8006657438770444
# abstfrac 0.3 distmaxclassprobfromone perf 0.8323861971115476
# abstfrac 0.15 entropy perf 0.8113021124104733
# abstfrac 0.3 entropy perf 0.8414843416964951
# abstfrac 0.15 variance perf 0.7664386368974963
# abstfrac 0.3 variance perf 0.8082987794194942
#
# noadapt base perf 0.7157270573587564
# abstfrac 0.15 estmarginalweightedkappa perf 0.7792081701560534
# abstfrac 0.3 estmarginalweightedkappa perf 0.8093529353956992
# abstfrac 0.15 jsdiv perf 0.7977237944995639
# abstfrac 0.3 jsdiv perf 0.8412794480759721
# abstfrac 0.15 distmaxclassprobfromone perf 0.7393932361978848
# abstfrac 0.3 distmaxclassprobfromone perf 0.7555687301422535
# abstfrac 0.15 entropy perf 0.7506530202732091
# abstfrac 0.3 entropy perf 0.7607933394383349
# abstfrac 0.15 variance perf 0.7284951573209446
# abstfrac 0.3 variance perf 0.7320775050266884
#
# on fold 8
#
# yesadapt base perf 0.7737509274068628
# abstfrac 0.15 estmarginalweightedkappa perf 0.8255105919436332
# abstfrac 0.3 estmarginalweightedkappa perf 0.8508023522592921
# abstfrac 0.15 jsdiv perf 0.8241247952273956
# abstfrac 0.3 jsdiv perf 0.8314787673583695
# abstfrac 0.15 distmaxclassprobfromone perf 0.7885210744936915
# abstfrac 0.3 distmaxclassprobfromone perf 0.8102455154372619
# abstfrac 0.15 entropy perf 0.79465044368422
# abstfrac 0.3 entropy perf 0.8172202057009208
# abstfrac 0.15 variance perf 0.7597174076972237
# abstfrac 0.3 variance perf 0.7791405412215529
#
# noadapt base perf 0.7259077233128755
# abstfrac 0.15 estmarginalweightedkappa perf 0.7915934540925351
# abstfrac 0.3 estmarginalweightedkappa perf 0.8177751154564148
# abstfrac 0.15 jsdiv perf 0.8108083880496806
# abstfrac 0.3 jsdiv perf 0.8344389550472939
# abstfrac 0.15 distmaxclassprobfromone perf 0.7595612177587834
# abstfrac 0.3 distmaxclassprobfromone perf 0.7687420867548913
# abstfrac 0.15 entropy perf 0.7671803040871366
# abstfrac 0.3 entropy perf 0.7769347858164337
# abstfrac 0.15 variance perf 0.7190337040262547
# abstfrac 0.3 variance perf 0.7390089970069409
#
# on fold 9
#
# yesadapt base perf 0.8091750651866382
# abstfrac 0.15 estmarginalweightedkappa perf 0.8550875809955969
# abstfrac 0.3 estmarginalweightedkappa perf 0.881239355096646
# abstfrac 0.15 jsdiv perf 0.8565790881096205
# abstfrac 0.3 jsdiv perf 0.864927081314363
# abstfrac 0.15 distmaxclassprobfromone perf 0.8527521088795849
# abstfrac 0.3 distmaxclassprobfromone perf 0.8740947974579951
# abstfrac 0.15 entropy perf 0.8533806425878407
# abstfrac 0.3 entropy perf 0.8733614979819827
# abstfrac 0.15 variance perf 0.7803876477865196
# abstfrac 0.3 variance perf 0.7594050522307281
#
# noadapt base perf 0.7156406646128809
# abstfrac 0.15 estmarginalweightedkappa perf 0.8018934583911008
# abstfrac 0.3 estmarginalweightedkappa perf 0.8396747126589252
# abstfrac 0.15 jsdiv perf 0.8192478296947927
# abstfrac 0.3 jsdiv perf 0.8701133370304266
# abstfrac 0.15 distmaxclassprobfromone perf 0.7475950719630198
# abstfrac 0.3 distmaxclassprobfromone perf 0.7734866280353204
# abstfrac 0.15 entropy perf 0.7616458022062351
# abstfrac 0.3 entropy perf 0.7824393527967013
# abstfrac 0.15 variance perf 0.7326702440384696
# abstfrac 0.3 variance perf 0.7550581713920069
#
# on fold 10
#
# yesadapt base perf 0.7803523049626553
# abstfrac 0.15 estmarginalweightedkappa perf 0.8245147059247009
# abstfrac 0.3 estmarginalweightedkappa perf 0.8425046119738883
# abstfrac 0.15 jsdiv perf 0.8256016633119174
# abstfrac 0.3 jsdiv perf 0.8319174726520085
# abstfrac 0.15 distmaxclassprobfromone perf 0.8036053864076637
# abstfrac 0.3 distmaxclassprobfromone perf 0.8114906145725393
# abstfrac 0.15 entropy perf 0.8146651713524246
# abstfrac 0.3 entropy perf 0.8308308261899466
# abstfrac 0.15 variance perf 0.7584898247388149
# abstfrac 0.3 variance perf 0.746888534210789
#
# noadapt base perf 0.7239512125699947
# abstfrac 0.15 estmarginalweightedkappa perf 0.779404954280309
# abstfrac 0.3 estmarginalweightedkappa perf 0.7989831699609315
# abstfrac 0.15 jsdiv perf 0.8003970636467747
# abstfrac 0.3 jsdiv perf 0.8266376197093042
# abstfrac 0.15 distmaxclassprobfromone perf 0.7522147686095662
# abstfrac 0.3 distmaxclassprobfromone perf 0.7564406977382133
# abstfrac 0.15 entropy perf 0.7533165933325031
# abstfrac 0.3 entropy perf 0.759854655245958
# abstfrac 0.15 variance perf 0.7055850520044742
# abstfrac 0.3 variance perf 0.7080667628932826
#
# on fold 11
#
# yesadapt base perf 0.7902751507598117
# abstfrac 0.15 estmarginalweightedkappa perf 0.846333808650747
# abstfrac 0.3 estmarginalweightedkappa perf 0.8715498493679985
# abstfrac 0.15 jsdiv perf 0.8456131817270108
# abstfrac 0.3 jsdiv perf 0.8490550924615655
# abstfrac 0.15 distmaxclassprobfromone perf 0.8195715059298057
# abstfrac 0.3 distmaxclassprobfromone perf 0.8467167659075926
# abstfrac 0.15 entropy perf 0.8313169244078127
# abstfrac 0.3 entropy perf 0.8592390890662359
# abstfrac 0.15 variance perf 0.7844475318320637
# abstfrac 0.3 variance perf 0.815897229128039
#
# noadapt base perf 0.7442500337738057
# abstfrac 0.15 estmarginalweightedkappa perf 0.8131835616869265
# abstfrac 0.3 estmarginalweightedkappa perf 0.8380697061148933
# abstfrac 0.15 jsdiv perf 0.8306559365950708
# abstfrac 0.3 jsdiv perf 0.859563254721803
# abstfrac 0.15 distmaxclassprobfromone perf 0.7793790886904735
# abstfrac 0.3 distmaxclassprobfromone perf 0.7939845552603313
# abstfrac 0.15 entropy perf 0.7825215354465597
# abstfrac 0.3 entropy perf 0.8017733317115863
# abstfrac 0.15 variance perf 0.7386269019886429
# abstfrac 0.3 variance perf 0.7701426944294372
#
# on fold 12
#
# yesadapt base perf 0.7519604912306689
# abstfrac 0.15 estmarginalweightedkappa perf 0.8127830306477223
# abstfrac 0.3 estmarginalweightedkappa perf 0.8445389522879005
# abstfrac 0.15 jsdiv perf 0.8115221329870304
# abstfrac 0.3 jsdiv perf 0.8285346456342546
# abstfrac 0.15 distmaxclassprobfromone perf 0.7837711099084089
# abstfrac 0.3 distmaxclassprobfromone perf 0.8101810803517617
# abstfrac 0.15 entropy perf 0.7971329721218035
# abstfrac 0.3 entropy perf 0.8257443375196478
# abstfrac 0.15 variance perf 0.7454298378351165
# abstfrac 0.3 variance perf 0.7781109666183174
#
# noadapt base perf 0.7200266909438817
# abstfrac 0.15 estmarginalweightedkappa perf 0.7791435558141804
# abstfrac 0.3 estmarginalweightedkappa perf 0.8047598406163523
# abstfrac 0.15 jsdiv perf 0.8006320474279605
# abstfrac 0.3 jsdiv perf 0.8317402873889528
# abstfrac 0.15 distmaxclassprobfromone perf 0.7452401748507629
# abstfrac 0.3 distmaxclassprobfromone perf 0.7600035795319925
# abstfrac 0.15 entropy perf 0.7555637063866856
# abstfrac 0.3 entropy perf 0.7637243053498926
# abstfrac 0.15 variance perf 0.7193875924734154
# abstfrac 0.3 variance perf 0.7356762468181175
#
# on fold 13
#
# yesadapt base perf 0.7333688761970482
# abstfrac 0.15 estmarginalweightedkappa perf 0.7955055297032061
# abstfrac 0.3 estmarginalweightedkappa perf 0.827944411897081
# abstfrac 0.15 jsdiv perf 0.7959817706570957
# abstfrac 0.3 jsdiv perf 0.8079023521887119
# abstfrac 0.15 distmaxclassprobfromone perf 0.7576117661332592
# abstfrac 0.3 distmaxclassprobfromone perf 0.7657420772999425
# abstfrac 0.15 entropy perf 0.7704048522378193
# abstfrac 0.3 entropy perf 0.7955070690671358
# abstfrac 0.15 variance perf 0.7155156751368152
# abstfrac 0.3 variance perf 0.7351526027229129
#
# noadapt base perf 0.6854715381099732
# abstfrac 0.15 estmarginalweightedkappa perf 0.763073433151438
# abstfrac 0.3 estmarginalweightedkappa perf 0.7902257255463991
# abstfrac 0.15 jsdiv perf 0.7828525060225281
# abstfrac 0.3 jsdiv perf 0.8130799496459586
# abstfrac 0.15 distmaxclassprobfromone perf 0.718528912113197
# abstfrac 0.3 distmaxclassprobfromone perf 0.7329255404495179
# abstfrac 0.15 entropy perf 0.7271718813792081
# abstfrac 0.3 entropy perf 0.7319947653714718
# abstfrac 0.15 variance perf 0.6812747607546132
# abstfrac 0.3 variance perf 0.6962726183001313
#
# on fold 14
#
# yesadapt base perf 0.7887862355959674
# abstfrac 0.15 estmarginalweightedkappa perf 0.8439415664303186
# abstfrac 0.3 estmarginalweightedkappa perf 0.860725133075916
# abstfrac 0.15 jsdiv perf 0.837231447328411
# abstfrac 0.3 jsdiv perf 0.8427314515864406
# abstfrac 0.15 distmaxclassprobfromone perf 0.8236539166924455
# abstfrac 0.3 distmaxclassprobfromone perf 0.8509904657973069
# abstfrac 0.15 entropy perf 0.8295182323461415
# abstfrac 0.3 entropy perf 0.8546913689486667
# abstfrac 0.15 variance perf 0.7872932584719449
# abstfrac 0.3 variance perf 0.8184691870098993
#
# noadapt base perf 0.7422629521634541
# abstfrac 0.15 estmarginalweightedkappa perf 0.8129057027320319
# abstfrac 0.3 estmarginalweightedkappa perf 0.8421070742204556
# abstfrac 0.15 jsdiv perf 0.8286632754877917
# abstfrac 0.3 jsdiv perf 0.8541465119004956
# abstfrac 0.15 distmaxclassprobfromone perf 0.7862238784745634
# abstfrac 0.3 distmaxclassprobfromone perf 0.8009697147517131
# abstfrac 0.15 entropy perf 0.7887833566291296
# abstfrac 0.3 entropy perf 0.8030531441974614
# abstfrac 0.15 variance perf 0.7491630791775251
# abstfrac 0.3 variance perf 0.7730648448172626
#
# on fold 15
#
# yesadapt base perf 0.8209961615276498
# abstfrac 0.15 estmarginalweightedkappa perf 0.865315575747236
# abstfrac 0.3 estmarginalweightedkappa perf 0.8848883661768372
# abstfrac 0.15 jsdiv perf 0.8633203072114723
# abstfrac 0.3 jsdiv perf 0.866523615693766
# abstfrac 0.15 distmaxclassprobfromone perf 0.8566157951324486
# abstfrac 0.3 distmaxclassprobfromone perf 0.8706427736035053
# abstfrac 0.15 entropy perf 0.8621553483254529
# abstfrac 0.3 entropy perf 0.86949157479118
# abstfrac 0.15 variance perf 0.7973466171442264
# abstfrac 0.3 variance perf 0.7925001752295507
#
# noadapt base perf 0.7580615940754842
# abstfrac 0.15 estmarginalweightedkappa perf 0.8233918755568042
# abstfrac 0.3 estmarginalweightedkappa perf 0.8547284289991512
# abstfrac 0.15 jsdiv perf 0.8369486734774473
# abstfrac 0.3 jsdiv perf 0.8710575263456324
# abstfrac 0.15 distmaxclassprobfromone perf 0.7965891036257703
# abstfrac 0.3 distmaxclassprobfromone perf 0.8183997197967025
# abstfrac 0.15 entropy perf 0.8048037026358182
# abstfrac 0.3 entropy perf 0.8234013154276771
# abstfrac 0.15 variance perf 0.7691279971645177
# abstfrac 0.3 variance perf 0.7899496131655174
#
# on fold 16
#
# yesadapt base perf 0.7836912851545063
# abstfrac 0.15 estmarginalweightedkappa perf 0.8351596335264347
# abstfrac 0.3 estmarginalweightedkappa perf 0.8639148718331808
# abstfrac 0.15 jsdiv perf 0.8375993476937101
# abstfrac 0.3 jsdiv perf 0.8507150586789202
# abstfrac 0.15 distmaxclassprobfromone perf 0.8140751609252267
# abstfrac 0.3 distmaxclassprobfromone perf 0.8392019036367778
# abstfrac 0.15 entropy perf 0.8282743599377422
# abstfrac 0.3 entropy perf 0.8578993471753347
# abstfrac 0.15 variance perf 0.7901521774832829
# abstfrac 0.3 variance perf 0.8034026330414888
#
# noadapt base perf 0.732617297589791
# abstfrac 0.15 estmarginalweightedkappa perf 0.8043140428323767
# abstfrac 0.3 estmarginalweightedkappa perf 0.829023348385606
# abstfrac 0.15 jsdiv perf 0.8237637195787213
# abstfrac 0.3 jsdiv perf 0.8596896871973797
# abstfrac 0.15 distmaxclassprobfromone perf 0.7663013715656812
# abstfrac 0.3 distmaxclassprobfromone perf 0.7936730169693473
# abstfrac 0.15 entropy perf 0.7771152703547262
# abstfrac 0.3 entropy perf 0.8001497730162255
# abstfrac 0.15 variance perf 0.751182058826574
# abstfrac 0.3 variance perf 0.7770133635876105
#
# on fold 17
#
# yesadapt base perf 0.810117513397824
# abstfrac 0.15 estmarginalweightedkappa perf 0.8479745365186572
# abstfrac 0.3 estmarginalweightedkappa perf 0.8689745669070285
# abstfrac 0.15 jsdiv perf 0.846330066968687
# abstfrac 0.3 jsdiv perf 0.8535826051769226
# abstfrac 0.15 distmaxclassprobfromone perf 0.8422421123400202
# abstfrac 0.3 distmaxclassprobfromone perf 0.85666375015069
# abstfrac 0.15 entropy perf 0.8465457471228963
# abstfrac 0.3 entropy perf 0.8599067915478937
# abstfrac 0.15 variance perf 0.7804687973487197
# abstfrac 0.3 variance perf 0.786392652140171
#
# noadapt base perf 0.7357714614260674
# abstfrac 0.15 estmarginalweightedkappa perf 0.811608931277753
# abstfrac 0.3 estmarginalweightedkappa perf 0.8448672856218821
# abstfrac 0.15 jsdiv perf 0.8299212999384749
# abstfrac 0.3 jsdiv perf 0.8605662577128762
# abstfrac 0.15 distmaxclassprobfromone perf 0.7735265995970445
# abstfrac 0.3 distmaxclassprobfromone perf 0.7945930953479335
# abstfrac 0.15 entropy perf 0.7820871899668123
# abstfrac 0.3 entropy perf 0.802958185103781
# abstfrac 0.15 variance perf 0.7367922672852577
# abstfrac 0.3 variance perf 0.766097487173031
#
# on fold 18
#
# yesadapt base perf 0.7798123009332069
# abstfrac 0.15 estmarginalweightedkappa perf 0.8296212455151127
# abstfrac 0.3 estmarginalweightedkappa perf 0.8530269307411149
# abstfrac 0.15 jsdiv perf 0.8316770949334922
# abstfrac 0.3 jsdiv perf 0.8484872746458061
# abstfrac 0.15 distmaxclassprobfromone perf 0.8175244913395701
# abstfrac 0.3 distmaxclassprobfromone perf 0.8367370108893362
# abstfrac 0.15 entropy perf 0.8224823516351758
# abstfrac 0.3 entropy perf 0.8492631427346684
# abstfrac 0.15 variance perf 0.7702779629903189
# abstfrac 0.3 variance perf 0.7638576839008816
#
# noadapt base perf 0.7204518798689306
# abstfrac 0.15 estmarginalweightedkappa perf 0.790325272871474
# abstfrac 0.3 estmarginalweightedkappa perf 0.8093772341241712
# abstfrac 0.15 jsdiv perf 0.8112409170169779
# abstfrac 0.3 jsdiv perf 0.8446913453367406
# abstfrac 0.15 distmaxclassprobfromone perf 0.7396600565565471
# abstfrac 0.3 distmaxclassprobfromone perf 0.7371465278404417
# abstfrac 0.15 entropy perf 0.7491649356210696
# abstfrac 0.3 entropy perf 0.7485412465333934
# abstfrac 0.15 variance perf 0.7160035992364626
# abstfrac 0.3 variance perf 0.7154273058027167
#
# on fold 19
#
# yesadapt base perf 0.7459745465221027
# abstfrac 0.15 estmarginalweightedkappa perf 0.8022441811022794
# abstfrac 0.3 estmarginalweightedkappa perf 0.8372853736345771
# abstfrac 0.15 jsdiv perf 0.8041741739419574
# abstfrac 0.3 jsdiv perf 0.8177816012121136
# abstfrac 0.15 distmaxclassprobfromone perf 0.7722847896533578
# abstfrac 0.3 distmaxclassprobfromone perf 0.8049383882389063
# abstfrac 0.15 entropy perf 0.7710054770966369
# abstfrac 0.3 entropy perf 0.8045179755654011
# abstfrac 0.15 variance perf 0.7541356059971522
# abstfrac 0.3 variance perf 0.7858947567281664
#
# noadapt base perf 0.7106452318013915
# abstfrac 0.15 estmarginalweightedkappa perf 0.7765154046199589
# abstfrac 0.3 estmarginalweightedkappa perf 0.8049583272034313
# abstfrac 0.15 jsdiv perf 0.7915251675864357
# abstfrac 0.3 jsdiv perf 0.8262852262677096
# abstfrac 0.15 distmaxclassprobfromone perf 0.7401699695384085
# abstfrac 0.3 distmaxclassprobfromone perf 0.7572625059132281
# abstfrac 0.15 entropy perf 0.7516609560931994
# abstfrac 0.3 entropy perf 0.7656026670808298
# abstfrac 0.15 variance perf 0.7213180403017465
# abstfrac 0.3 variance perf 0.7390667703168483
#
# on fold 20
#
# yesadapt base perf 0.7752332565404078
# abstfrac 0.15 estmarginalweightedkappa perf 0.8221707914733112
# abstfrac 0.3 estmarginalweightedkappa perf 0.8442457646447846
# abstfrac 0.15 jsdiv perf 0.8261976355357998
# abstfrac 0.3 jsdiv perf 0.83288100506798
# abstfrac 0.15 distmaxclassprobfromone perf 0.8066127966041179
# abstfrac 0.3 distmaxclassprobfromone perf 0.8341008294239992
# abstfrac 0.15 entropy perf 0.8146885997813034
# abstfrac 0.3 entropy perf 0.8431669243453445
# abstfrac 0.15 variance perf 0.7801710644615026
# abstfrac 0.3 variance perf 0.7981856766737084
#
# noadapt base perf 0.7420288361185914
# abstfrac 0.15 estmarginalweightedkappa perf 0.792425028523169
# abstfrac 0.3 estmarginalweightedkappa perf 0.8160968743293675
# abstfrac 0.15 jsdiv perf 0.8194474472795381
# abstfrac 0.3 jsdiv perf 0.8489954502664996
# abstfrac 0.15 distmaxclassprobfromone perf 0.7623704412613613
# abstfrac 0.3 distmaxclassprobfromone perf 0.782659328698204
# abstfrac 0.15 entropy perf 0.7699612562518292
# abstfrac 0.3 entropy perf 0.7903313766965415
# abstfrac 0.15 variance perf 0.728359821917985
# abstfrac 0.3 variance perf 0.7487150014584198
#
# on fold 21
#
# yesadapt base perf 0.8224597492403869
# abstfrac 0.15 estmarginalweightedkappa perf 0.8399900045155435
# abstfrac 0.3 estmarginalweightedkappa perf 0.8494412060451652
# abstfrac 0.15 jsdiv perf 0.8399775393995202
# abstfrac 0.3 jsdiv perf 0.8320724360500287
# abstfrac 0.15 distmaxclassprobfromone perf 0.8456712162452891
# abstfrac 0.3 distmaxclassprobfromone perf 0.8605222680965408
# abstfrac 0.15 entropy perf 0.842575812966647
# abstfrac 0.3 entropy perf 0.8584112584492636
# abstfrac 0.15 variance perf 0.8067784151302865
# abstfrac 0.3 variance perf 0.7952746826956034
#
# noadapt base perf 0.7773338580730016
# abstfrac 0.15 estmarginalweightedkappa perf 0.8276934750840392
# abstfrac 0.3 estmarginalweightedkappa perf 0.843944898328901
# abstfrac 0.15 jsdiv perf 0.8440656681200452
# abstfrac 0.3 jsdiv perf 0.8558803963751449
# abstfrac 0.15 distmaxclassprobfromone perf 0.801484497861381
# abstfrac 0.3 distmaxclassprobfromone perf 0.8189006808255566
# abstfrac 0.15 entropy perf 0.8088523779756188
# abstfrac 0.3 entropy perf 0.8229675322407968
# abstfrac 0.15 variance perf 0.7707447059297127
# abstfrac 0.3 variance perf 0.7842628760290771
#
# on fold 22
#
# yesadapt base perf 0.8074754894181795
# abstfrac 0.15 estmarginalweightedkappa perf 0.8525344356969078
# abstfrac 0.3 estmarginalweightedkappa perf 0.8700692491047322
# abstfrac 0.15 jsdiv perf 0.8474439307145015
# abstfrac 0.3 jsdiv perf 0.8482504065081674
# abstfrac 0.15 distmaxclassprobfromone perf 0.8304873709981102
# abstfrac 0.3 distmaxclassprobfromone perf 0.858796600260088
# abstfrac 0.15 entropy perf 0.845247456930735
# abstfrac 0.3 entropy perf 0.8717022593547329
# abstfrac 0.15 variance perf 0.808857680884121
# abstfrac 0.3 variance perf 0.8354988405978289
#
# noadapt base perf 0.7563277709722688
# abstfrac 0.15 estmarginalweightedkappa perf 0.8229764253701732
# abstfrac 0.3 estmarginalweightedkappa perf 0.8470311804016617
# abstfrac 0.15 jsdiv perf 0.841222660362725
# abstfrac 0.3 jsdiv perf 0.8632442770577948
# abstfrac 0.15 distmaxclassprobfromone perf 0.795262769257369
# abstfrac 0.3 distmaxclassprobfromone perf 0.8262921089615195
# abstfrac 0.15 entropy perf 0.8041305233712458
# abstfrac 0.3 entropy perf 0.8313869978941066
# abstfrac 0.15 variance perf 0.77191523383433
# abstfrac 0.3 variance perf 0.7956154217454501
#
# on fold 23
#
# yesadapt base perf 0.7867952188114309
# abstfrac 0.15 estmarginalweightedkappa perf 0.8350812309563191
# abstfrac 0.3 estmarginalweightedkappa perf 0.8492876336869167
# abstfrac 0.15 jsdiv perf 0.834671666786978
# abstfrac 0.3 jsdiv perf 0.8294964049876382
# abstfrac 0.15 distmaxclassprobfromone perf 0.8195153476105705
# abstfrac 0.3 distmaxclassprobfromone perf 0.8377850468472599
# abstfrac 0.15 entropy perf 0.8268328467047253
# abstfrac 0.3 entropy perf 0.8414525281752497
# abstfrac 0.15 variance perf 0.7837038179435157
# abstfrac 0.3 variance perf 0.8126921370406716
#
# noadapt base perf 0.7315507550686651
# abstfrac 0.15 estmarginalweightedkappa perf 0.8001134029243082
# abstfrac 0.3 estmarginalweightedkappa perf 0.8297265586335224
# abstfrac 0.15 jsdiv perf 0.8191869751587638
# abstfrac 0.3 jsdiv perf 0.8397573778754883
# abstfrac 0.15 distmaxclassprobfromone perf 0.774076074133518
# abstfrac 0.3 distmaxclassprobfromone perf 0.7933774384605543
# abstfrac 0.15 entropy perf 0.7790383395307645
# abstfrac 0.3 entropy perf 0.7973510812170723
# abstfrac 0.15 variance perf 0.738980936605201
# abstfrac 0.3 variance perf 0.7700646222489229
#
# on fold 24
#
# yesadapt base perf 0.7932048047565187
# abstfrac 0.15 estmarginalweightedkappa perf 0.8468898188444157
# abstfrac 0.3 estmarginalweightedkappa perf 0.8668383145584063
# abstfrac 0.15 jsdiv perf 0.8381075551528983
# abstfrac 0.3 jsdiv perf 0.8493317547574829
# abstfrac 0.15 distmaxclassprobfromone perf 0.8309352722173757
# abstfrac 0.3 distmaxclassprobfromone perf 0.8480431830799382
# abstfrac 0.15 entropy perf 0.8325707633949733
# abstfrac 0.3 entropy perf 0.8454194901702771
# abstfrac 0.15 variance perf 0.7593888222941523
# abstfrac 0.3 variance perf 0.7909812325935212
#
# noadapt base perf 0.7407710695304538
# abstfrac 0.15 estmarginalweightedkappa perf 0.8224963442579611
# abstfrac 0.3 estmarginalweightedkappa perf 0.8450708441855592
# abstfrac 0.15 jsdiv perf 0.8264886829449237
# abstfrac 0.3 jsdiv perf 0.8553285765249489
# abstfrac 0.15 distmaxclassprobfromone perf 0.7840756164499687
# abstfrac 0.3 distmaxclassprobfromone perf 0.8086909817822499
# abstfrac 0.15 entropy perf 0.797599207644472
# abstfrac 0.3 entropy perf 0.8158180280381614
# abstfrac 0.15 variance perf 0.7528475398986779
# abstfrac 0.3 variance perf 0.789480797048857
#
# on fold 25
#
# yesadapt base perf 0.7804405600303034
# abstfrac 0.15 estmarginalweightedkappa perf 0.8283918126776149
# abstfrac 0.3 estmarginalweightedkappa perf 0.8502831131718284
# abstfrac 0.15 jsdiv perf 0.8218783819052702
# abstfrac 0.3 jsdiv perf 0.8269950182527925
# abstfrac 0.15 distmaxclassprobfromone perf 0.7938920645450931
# abstfrac 0.3 distmaxclassprobfromone perf 0.8135612203258805
# abstfrac 0.15 entropy perf 0.7979222575932329
# abstfrac 0.3 entropy perf 0.8207931294033236
# abstfrac 0.15 variance perf 0.7702839964540521
# abstfrac 0.3 variance perf 0.7981517262030866
#
# noadapt base perf 0.7509044176086493
# abstfrac 0.15 estmarginalweightedkappa perf 0.8134098943364191
# abstfrac 0.3 estmarginalweightedkappa perf 0.8383619697074872
# abstfrac 0.15 jsdiv perf 0.8205212584826919
# abstfrac 0.3 jsdiv perf 0.8374779762287952
# abstfrac 0.15 distmaxclassprobfromone perf 0.788419180359905
# abstfrac 0.3 distmaxclassprobfromone perf 0.8017721938476455
# abstfrac 0.15 entropy perf 0.7940702021541992
# abstfrac 0.3 entropy perf 0.8053353387976715
# abstfrac 0.15 variance perf 0.751368681739957
# abstfrac 0.3 variance perf 0.7876433076932976
#
# on fold 26
#
# yesadapt base perf 0.7370274343818333
# abstfrac 0.15 estmarginalweightedkappa perf 0.7967835412972252
# abstfrac 0.3 estmarginalweightedkappa perf 0.8293140470352716
# abstfrac 0.15 jsdiv perf 0.7962281641041992
# abstfrac 0.3 jsdiv perf 0.8020666803611778
# abstfrac 0.15 distmaxclassprobfromone perf 0.7815729246535201
# abstfrac 0.3 distmaxclassprobfromone perf 0.8207068389403874
# abstfrac 0.15 entropy perf 0.7820052774310399
# abstfrac 0.3 entropy perf 0.8202398751383952
# abstfrac 0.15 variance perf 0.7551138941479063
# abstfrac 0.3 variance perf 0.7974000714041325
#
# noadapt base perf 0.6970453157945145
# abstfrac 0.15 estmarginalweightedkappa perf 0.7633728155131962
# abstfrac 0.3 estmarginalweightedkappa perf 0.797074913475494
# abstfrac 0.15 jsdiv perf 0.7824854702447923
# abstfrac 0.3 jsdiv perf 0.8187592022725667
# abstfrac 0.15 distmaxclassprobfromone perf 0.733978782061818
# abstfrac 0.3 distmaxclassprobfromone perf 0.7543524819180096
# abstfrac 0.15 entropy perf 0.7371800881618367
# abstfrac 0.3 entropy perf 0.7545288240536611
# abstfrac 0.15 variance perf 0.7080187300279064
# abstfrac 0.3 variance perf 0.7338052132785978
#
# on fold 27
#
# yesadapt base perf 0.7776070872421823
# abstfrac 0.15 estmarginalweightedkappa perf 0.8274743446983388
# abstfrac 0.3 estmarginalweightedkappa perf 0.855575173481139
# abstfrac 0.15 jsdiv perf 0.8287546982888121
# abstfrac 0.3 jsdiv perf 0.8437045008545927
# abstfrac 0.15 distmaxclassprobfromone perf 0.8037458328765252
# abstfrac 0.3 distmaxclassprobfromone perf 0.8210925357565908
# abstfrac 0.15 entropy perf 0.821610155205991
# abstfrac 0.3 entropy perf 0.8449943359760442
# abstfrac 0.15 variance perf 0.7660369113952628
# abstfrac 0.3 variance perf 0.7773427876373575
#
# noadapt base perf 0.7170854337188051
# abstfrac 0.15 estmarginalweightedkappa perf 0.7849000430486905
# abstfrac 0.3 estmarginalweightedkappa perf 0.8066047813128686
# abstfrac 0.15 jsdiv perf 0.800670573596877
# abstfrac 0.3 jsdiv perf 0.8315269793197196
# abstfrac 0.15 distmaxclassprobfromone perf 0.7511390041191564
# abstfrac 0.3 distmaxclassprobfromone perf 0.759553385001184
# abstfrac 0.15 entropy perf 0.75542356509367
# abstfrac 0.3 entropy perf 0.7645012337578936
# abstfrac 0.15 variance perf 0.7305268363959536
# abstfrac 0.3 variance perf 0.7570452699534339
#
# on fold 28
#
# yesadapt base perf 0.776906073434172
# abstfrac 0.15 estmarginalweightedkappa perf 0.8355764624969351
# abstfrac 0.3 estmarginalweightedkappa perf 0.8590981759068435
# abstfrac 0.15 jsdiv perf 0.830839258818409
# abstfrac 0.3 jsdiv perf 0.8471811406375529
# abstfrac 0.15 distmaxclassprobfromone perf 0.8038235430631586
# abstfrac 0.3 distmaxclassprobfromone perf 0.8191514113531925
# abstfrac 0.15 entropy perf 0.8207279408067923
# abstfrac 0.3 entropy perf 0.8393833497775824
# abstfrac 0.15 variance perf 0.7673252621770251
# abstfrac 0.3 variance perf 0.7782696236620626
#
# noadapt base perf 0.7249019676756925
# abstfrac 0.15 estmarginalweightedkappa perf 0.7814091171482824
# abstfrac 0.3 estmarginalweightedkappa perf 0.8052051704532269
# abstfrac 0.15 jsdiv perf 0.8015600980768329
# abstfrac 0.3 jsdiv perf 0.8350863666837001
# abstfrac 0.15 distmaxclassprobfromone perf 0.7425192820743592
# abstfrac 0.3 distmaxclassprobfromone perf 0.7554286662236442
# abstfrac 0.15 entropy perf 0.7488742201136186
# abstfrac 0.3 entropy perf 0.7606242920469339
# abstfrac 0.15 variance perf 0.7200284904967238
# abstfrac 0.3 variance perf 0.7333359004920905
#
# on fold 29
#
# yesadapt base perf 0.7709913818211069
# abstfrac 0.15 estmarginalweightedkappa perf 0.8309468714162066
# abstfrac 0.3 estmarginalweightedkappa perf 0.8598111939187499
# abstfrac 0.15 jsdiv perf 0.8325197850492178
# abstfrac 0.3 jsdiv perf 0.8428457873208692
# abstfrac 0.15 distmaxclassprobfromone perf 0.8044094294914375
# abstfrac 0.3 distmaxclassprobfromone perf 0.8412616520750849
# abstfrac 0.15 entropy perf 0.7966760735317944
# abstfrac 0.3 entropy perf 0.8337431081460605
# abstfrac 0.15 variance perf 0.7866347016603406
# abstfrac 0.3 variance perf 0.8184138485215804
#
# noadapt base perf 0.7470866685517901
# abstfrac 0.15 estmarginalweightedkappa perf 0.7954279342651388
# abstfrac 0.3 estmarginalweightedkappa perf 0.8215499183314738
# abstfrac 0.15 jsdiv perf 0.8147400869145938
# abstfrac 0.3 jsdiv perf 0.851948418998775
# abstfrac 0.15 distmaxclassprobfromone perf 0.7718330895053072
# abstfrac 0.3 distmaxclassprobfromone perf 0.7775053986706988
# abstfrac 0.15 entropy perf 0.7696951464113211
# abstfrac 0.3 entropy perf 0.7731818933741728
# abstfrac 0.15 variance perf 0.7383145096361707
# abstfrac 0.3 variance perf 0.7563702877437691
#
# useweightrescalepreds True
# labelshift False
#
# on fold 0
#
# yescalib base perf 0.7924186476052724
# abstfrac 0.15 estmarginalweightedkappa perf 0.8630670087407657
# abstfrac 0.3 estmarginalweightedkappa perf 0.8833661457450763
# abstfrac 0.15 jsdiv perf 0.8305077512153878
# abstfrac 0.3 jsdiv perf 0.8405579125269269
# abstfrac 0.15 distmaxclassprobfromone perf 0.8072194026450222
# abstfrac 0.3 distmaxclassprobfromone perf 0.7396387286452162
# abstfrac 0.15 entropy perf 0.8290583272525174
# abstfrac 0.3 entropy perf 0.754415148914181
# abstfrac 0.15 variance perf 0.7468435218712379
# abstfrac 0.3 variance perf 0.6561666054706936
#
# nocalib base perf 0.7924186476052724
# abstfrac 0.15 estmarginalweightedkappa perf 0.8622378164010063
# abstfrac 0.3 estmarginalweightedkappa perf 0.8901914937699016
# abstfrac 0.15 jsdiv perf 0.8364748800232524
# abstfrac 0.3 jsdiv perf 0.8494187215366834
# abstfrac 0.15 distmaxclassprobfromone perf 0.8034791032675533
# abstfrac 0.3 distmaxclassprobfromone perf 0.7381610335624366
# abstfrac 0.15 entropy perf 0.8162687097270241
# abstfrac 0.3 entropy perf 0.7408301135235364
# abstfrac 0.15 variance perf 0.7541278359990922
# abstfrac 0.3 variance perf 0.6625375706515348
#
# on fold 1
#
# yescalib base perf 0.8122923807819769
# abstfrac 0.15 estmarginalweightedkappa perf 0.8726415012966813
# abstfrac 0.3 estmarginalweightedkappa perf 0.8936301088987105
# abstfrac 0.15 jsdiv perf 0.843272945179266
# abstfrac 0.3 jsdiv perf 0.8532465072246667
# abstfrac 0.15 distmaxclassprobfromone perf 0.8250472934925446
# abstfrac 0.3 distmaxclassprobfromone perf 0.7693542047603803
# abstfrac 0.15 entropy perf 0.8413707084371738
# abstfrac 0.3 entropy perf 0.7780518669198966
# abstfrac 0.15 variance perf 0.7731632699895591
# abstfrac 0.3 variance perf 0.6395599839563717
#
# nocalib base perf 0.8122923807819769
# abstfrac 0.15 estmarginalweightedkappa perf 0.8746128259634498
# abstfrac 0.3 estmarginalweightedkappa perf 0.899159945478059
# abstfrac 0.15 jsdiv perf 0.849931645411212
# abstfrac 0.3 jsdiv perf 0.8615924542912612
# abstfrac 0.15 distmaxclassprobfromone perf 0.8241852773086648
# abstfrac 0.3 distmaxclassprobfromone perf 0.7724920402745383
# abstfrac 0.15 entropy perf 0.8308771762389109
# abstfrac 0.3 entropy perf 0.7709963790644628
# abstfrac 0.15 variance perf 0.7807359361952954
# abstfrac 0.3 variance perf 0.6609133123225627
#
# on fold 2
#
# yescalib base perf 0.8205617335643102
# abstfrac 0.15 estmarginalweightedkappa perf 0.876855956888098
# abstfrac 0.3 estmarginalweightedkappa perf 0.8934932578012915
# abstfrac 0.15 jsdiv perf 0.8458230359790209
# abstfrac 0.3 jsdiv perf 0.8560269056948009
# abstfrac 0.15 distmaxclassprobfromone perf 0.8412865951092386
# abstfrac 0.3 distmaxclassprobfromone perf 0.7987322549212397
# abstfrac 0.15 entropy perf 0.8574165680236293
# abstfrac 0.3 entropy perf 0.8107615472209126
# abstfrac 0.15 variance perf 0.7963009534158283
# abstfrac 0.3 variance perf 0.7133074801587755
#
# nocalib base perf 0.8205617335643102
# abstfrac 0.15 estmarginalweightedkappa perf 0.8781328899982876
# abstfrac 0.3 estmarginalweightedkappa perf 0.8993815108879406
# abstfrac 0.15 jsdiv perf 0.8510728202799815
# abstfrac 0.3 jsdiv perf 0.8626864758202497
# abstfrac 0.15 distmaxclassprobfromone perf 0.8380025114006887
# abstfrac 0.3 distmaxclassprobfromone perf 0.7972878110943256
# abstfrac 0.15 entropy perf 0.8467331614752117
# abstfrac 0.3 entropy perf 0.7973438679110668
# abstfrac 0.15 variance perf 0.8093376390579193
# abstfrac 0.3 variance perf 0.7419059169209641
#
# on fold 3
#
# yescalib base perf 0.82213800181851
# abstfrac 0.15 estmarginalweightedkappa perf 0.883532674107324
# abstfrac 0.3 estmarginalweightedkappa perf 0.9025836236952717
# abstfrac 0.15 jsdiv perf 0.855408554173068
# abstfrac 0.3 jsdiv perf 0.865169630397534
# abstfrac 0.15 distmaxclassprobfromone perf 0.8438174795342429
# abstfrac 0.3 distmaxclassprobfromone perf 0.795450445282483
# abstfrac 0.15 entropy perf 0.8585320182610054
# abstfrac 0.3 entropy perf 0.8114933817523124
# abstfrac 0.15 variance perf 0.7987453021913162
# abstfrac 0.3 variance perf 0.7143398339492102
#
# nocalib base perf 0.82213800181851
# abstfrac 0.15 estmarginalweightedkappa perf 0.8848095835476303
# abstfrac 0.3 estmarginalweightedkappa perf 0.9113584438781323
# abstfrac 0.15 jsdiv perf 0.863364993021497
# abstfrac 0.3 jsdiv perf 0.871236529028911
# abstfrac 0.15 distmaxclassprobfromone perf 0.841006352154573
# abstfrac 0.3 distmaxclassprobfromone perf 0.7940112466306339
# abstfrac 0.15 entropy perf 0.8495200596782169
# abstfrac 0.3 entropy perf 0.7934986103174733
# abstfrac 0.15 variance perf 0.8054158397132414
# abstfrac 0.3 variance perf 0.7428952565446256
#
# on fold 4
#
# yescalib base perf 0.7985929741214055
# abstfrac 0.15 estmarginalweightedkappa perf 0.8616431722551211
# abstfrac 0.3 estmarginalweightedkappa perf 0.889810403923297
# abstfrac 0.15 jsdiv perf 0.8393611968447519
# abstfrac 0.3 jsdiv perf 0.8526090685265063
# abstfrac 0.15 distmaxclassprobfromone perf 0.8082327797509953
# abstfrac 0.3 distmaxclassprobfromone perf 0.7663384197258879
# abstfrac 0.15 entropy perf 0.8320166701863356
# abstfrac 0.3 entropy perf 0.7700351918890549
# abstfrac 0.15 variance perf 0.7545035802495619
# abstfrac 0.3 variance perf 0.6945611305105315
#
# nocalib base perf 0.7985929741214055
# abstfrac 0.15 estmarginalweightedkappa perf 0.8618703472415817
# abstfrac 0.3 estmarginalweightedkappa perf 0.8951923216029513
# abstfrac 0.15 jsdiv perf 0.8442639370435001
# abstfrac 0.3 jsdiv perf 0.8579064615482971
# abstfrac 0.15 distmaxclassprobfromone perf 0.8034795250012289
# abstfrac 0.3 distmaxclassprobfromone perf 0.7660818276750896
# abstfrac 0.15 entropy perf 0.8169371252570469
# abstfrac 0.3 entropy perf 0.7665634773534453
# abstfrac 0.15 variance perf 0.7579667560024497
# abstfrac 0.3 variance perf 0.7114139908610564
#
# on fold 5
#
# yescalib base perf 0.7971906794522555
# abstfrac 0.15 estmarginalweightedkappa perf 0.8605006393384618
# abstfrac 0.3 estmarginalweightedkappa perf 0.8825228664908219
# abstfrac 0.15 jsdiv perf 0.8325769976616184
# abstfrac 0.3 jsdiv perf 0.8463408117470478
# abstfrac 0.15 distmaxclassprobfromone perf 0.7915152945198527
# abstfrac 0.3 distmaxclassprobfromone perf 0.6656987739704248
# abstfrac 0.15 entropy perf 0.8129456610983995
# abstfrac 0.3 entropy perf 0.6805203731908479
# abstfrac 0.15 variance perf 0.73286869427968
# abstfrac 0.3 variance perf 0.5419849246432388
#
# nocalib base perf 0.7971906794522555
# abstfrac 0.15 estmarginalweightedkappa perf 0.8590142586588462
# abstfrac 0.3 estmarginalweightedkappa perf 0.8853717804484089
# abstfrac 0.15 jsdiv perf 0.8380854348686112
# abstfrac 0.3 jsdiv perf 0.8503807680181932
# abstfrac 0.15 distmaxclassprobfromone perf 0.7874616876415516
# abstfrac 0.3 distmaxclassprobfromone perf 0.6679688043631213
# abstfrac 0.15 entropy perf 0.797819607565365
# abstfrac 0.3 entropy perf 0.6629592411447197
# abstfrac 0.15 variance perf 0.7417043908040661
# abstfrac 0.3 variance perf 0.5575609622532347
#
# on fold 6
#
# yescalib base perf 0.8080208470264123
# abstfrac 0.15 estmarginalweightedkappa perf 0.8737823909412286
# abstfrac 0.3 estmarginalweightedkappa perf 0.8917199263934223
# abstfrac 0.15 jsdiv perf 0.8401665389346782
# abstfrac 0.3 jsdiv perf 0.8502663009712359
# abstfrac 0.15 distmaxclassprobfromone perf 0.8239295812425325
# abstfrac 0.3 distmaxclassprobfromone perf 0.7591594561740185
# abstfrac 0.15 entropy perf 0.8443732722822315
# abstfrac 0.3 entropy perf 0.7753004631776352
# abstfrac 0.15 variance perf 0.7680585981004727
# abstfrac 0.3 variance perf 0.6798744295290899
#
# nocalib base perf 0.8080208470264123
# abstfrac 0.15 estmarginalweightedkappa perf 0.8724942003753697
# abstfrac 0.3 estmarginalweightedkappa perf 0.8973109859883939
# abstfrac 0.15 jsdiv perf 0.8467685480204313
# abstfrac 0.3 jsdiv perf 0.8592627545509903
# abstfrac 0.15 distmaxclassprobfromone perf 0.8187231404245928
# abstfrac 0.3 distmaxclassprobfromone perf 0.7589948186021656
# abstfrac 0.15 entropy perf 0.8295953922578467
# abstfrac 0.3 entropy perf 0.7585702444069304
# abstfrac 0.15 variance perf 0.7784726489594774
# abstfrac 0.3 variance perf 0.6977593601793638
#
# on fold 7
#
# yescalib base perf 0.8076245607752377
# abstfrac 0.15 estmarginalweightedkappa perf 0.8702153312562472
# abstfrac 0.3 estmarginalweightedkappa perf 0.8966451955399543
# abstfrac 0.15 jsdiv perf 0.8476495310890992
# abstfrac 0.3 jsdiv perf 0.8652995488351987
# abstfrac 0.15 distmaxclassprobfromone perf 0.8113284506348832
# abstfrac 0.3 distmaxclassprobfromone perf 0.7388179008770441
# abstfrac 0.15 entropy perf 0.833362870031225
# abstfrac 0.3 entropy perf 0.7586605654595461
# abstfrac 0.15 variance perf 0.7620374007380795
# abstfrac 0.3 variance perf 0.6663838796922698
#
# nocalib base perf 0.8076245607752377
# abstfrac 0.15 estmarginalweightedkappa perf 0.8695485873279223
# abstfrac 0.3 estmarginalweightedkappa perf 0.9030433548393653
# abstfrac 0.15 jsdiv perf 0.8521835576464251
# abstfrac 0.3 jsdiv perf 0.8707049639631104
# abstfrac 0.15 distmaxclassprobfromone perf 0.8076108842358931
# abstfrac 0.3 distmaxclassprobfromone perf 0.7359339433322212
# abstfrac 0.15 entropy perf 0.8168987732929099
# abstfrac 0.3 entropy perf 0.738010819340076
# abstfrac 0.15 variance perf 0.7655941940188166
# abstfrac 0.3 variance perf 0.6833268197994558
#
# on fold 8
#
# yescalib base perf 0.8052202745904868
# abstfrac 0.15 estmarginalweightedkappa perf 0.8662898937413623
# abstfrac 0.3 estmarginalweightedkappa perf 0.8869719730572727
# abstfrac 0.15 jsdiv perf 0.8364914731474512
# abstfrac 0.3 jsdiv perf 0.8476664263743751
# abstfrac 0.15 distmaxclassprobfromone perf 0.8138443293435498
# abstfrac 0.3 distmaxclassprobfromone perf 0.7347343999537556
# abstfrac 0.15 entropy perf 0.8317352056156825
# abstfrac 0.3 entropy perf 0.7420364595335885
# abstfrac 0.15 variance perf 0.7613159336210616
# abstfrac 0.3 variance perf 0.5978737917808924
#
# nocalib base perf 0.8052202745904868
# abstfrac 0.15 estmarginalweightedkappa perf 0.8690423007657267
# abstfrac 0.3 estmarginalweightedkappa perf 0.8928937940401679
# abstfrac 0.15 jsdiv perf 0.841080161978612
# abstfrac 0.3 jsdiv perf 0.8551471577104042
# abstfrac 0.15 distmaxclassprobfromone perf 0.8110897160783059
# abstfrac 0.3 distmaxclassprobfromone perf 0.7368262116865469
# abstfrac 0.15 entropy perf 0.818903500643022
# abstfrac 0.3 entropy perf 0.7337684499610065
# abstfrac 0.15 variance perf 0.7663442751970306
# abstfrac 0.3 variance perf 0.6145159035014847
#
# on fold 9
#
# yescalib base perf 0.8162423670633439
# abstfrac 0.15 estmarginalweightedkappa perf 0.8844363076433335
# abstfrac 0.3 estmarginalweightedkappa perf 0.9054384256094772
# abstfrac 0.15 jsdiv perf 0.8488772972001009
# abstfrac 0.3 jsdiv perf 0.858267271939761
# abstfrac 0.15 distmaxclassprobfromone perf 0.8438712970394021
# abstfrac 0.3 distmaxclassprobfromone perf 0.7795272492753338
# abstfrac 0.15 entropy perf 0.8640022680765738
# abstfrac 0.3 entropy perf 0.7986129017110951
# abstfrac 0.15 variance perf 0.7854783062387264
# abstfrac 0.3 variance perf 0.6524105546757148
#
# nocalib base perf 0.8162423670633439
# abstfrac 0.15 estmarginalweightedkappa perf 0.8867157368532406
# abstfrac 0.3 estmarginalweightedkappa perf 0.9124968886159459
# abstfrac 0.15 jsdiv perf 0.8577502225557986
# abstfrac 0.3 jsdiv perf 0.8678108936675448
# abstfrac 0.15 distmaxclassprobfromone perf 0.8374963530124407
# abstfrac 0.3 distmaxclassprobfromone perf 0.7808488337248032
# abstfrac 0.15 entropy perf 0.8546074499261134
# abstfrac 0.3 entropy perf 0.7781309278338588
# abstfrac 0.15 variance perf 0.799415727801686
# abstfrac 0.3 variance perf 0.6906553963695259
#
# on fold 10
#
# yescalib base perf 0.8061186219706035
# abstfrac 0.15 estmarginalweightedkappa perf 0.8618732665057607
# abstfrac 0.3 estmarginalweightedkappa perf 0.8828167115608521
# abstfrac 0.15 jsdiv perf 0.834216258150107
# abstfrac 0.3 jsdiv perf 0.8464154564293283
# abstfrac 0.15 distmaxclassprobfromone perf 0.8060548339378711
# abstfrac 0.3 distmaxclassprobfromone perf 0.7068402667565946
# abstfrac 0.15 entropy perf 0.83036332676285
# abstfrac 0.3 entropy perf 0.7285101815148438
# abstfrac 0.15 variance perf 0.7319080771234707
# abstfrac 0.3 variance perf 0.5612455824498234
#
# nocalib base perf 0.8061186219706035
# abstfrac 0.15 estmarginalweightedkappa perf 0.8599544510822944
# abstfrac 0.3 estmarginalweightedkappa perf 0.8870845575059993
# abstfrac 0.15 jsdiv perf 0.839423005500744
# abstfrac 0.3 jsdiv perf 0.8531230352003819
# abstfrac 0.15 distmaxclassprobfromone perf 0.8024447658578677
# abstfrac 0.3 distmaxclassprobfromone perf 0.7096925975759538
# abstfrac 0.15 entropy perf 0.8134681779415824
# abstfrac 0.3 entropy perf 0.7076704339072407
# abstfrac 0.15 variance perf 0.7475123382569084
# abstfrac 0.3 variance perf 0.5834711121753728
#
# on fold 11
#
# yescalib base perf 0.8128198820016795
# abstfrac 0.15 estmarginalweightedkappa perf 0.8763616589734777
# abstfrac 0.3 estmarginalweightedkappa perf 0.8943398319544088
# abstfrac 0.15 jsdiv perf 0.8469014940870078
# abstfrac 0.3 jsdiv perf 0.8560538674183946
# abstfrac 0.15 distmaxclassprobfromone perf 0.8285754271264477
# abstfrac 0.3 distmaxclassprobfromone perf 0.7565842474712396
# abstfrac 0.15 entropy perf 0.850173830963413
# abstfrac 0.3 entropy perf 0.7757617360494073
# abstfrac 0.15 variance perf 0.7732227114209174
# abstfrac 0.3 variance perf 0.6567027994151916
#
# nocalib base perf 0.8128198820016795
# abstfrac 0.15 estmarginalweightedkappa perf 0.8778105840124304
# abstfrac 0.3 estmarginalweightedkappa perf 0.9029448286621131
# abstfrac 0.15 jsdiv perf 0.8522337045727874
# abstfrac 0.3 jsdiv perf 0.8605711595742171
# abstfrac 0.15 distmaxclassprobfromone perf 0.8210150603944647
# abstfrac 0.3 distmaxclassprobfromone perf 0.7567620613946578
# abstfrac 0.15 entropy perf 0.8379569906686962
# abstfrac 0.3 entropy perf 0.7559034102101516
# abstfrac 0.15 variance perf 0.7743275241155584
# abstfrac 0.3 variance perf 0.6836731998515115
#
# on fold 12
#
# yescalib base perf 0.7982557382696003
# abstfrac 0.15 estmarginalweightedkappa perf 0.8608745276558178
# abstfrac 0.3 estmarginalweightedkappa perf 0.8844181979966207
# abstfrac 0.15 jsdiv perf 0.8328021847842892
# abstfrac 0.3 jsdiv perf 0.846105958018891
# abstfrac 0.15 distmaxclassprobfromone perf 0.8122348921893947
# abstfrac 0.3 distmaxclassprobfromone perf 0.7251366775816457
# abstfrac 0.15 entropy perf 0.8324725165528335
# abstfrac 0.3 entropy perf 0.7447161426414319
# abstfrac 0.15 variance perf 0.7462204645711392
# abstfrac 0.3 variance perf 0.6123789521059804
#
# nocalib base perf 0.7982557382696003
# abstfrac 0.15 estmarginalweightedkappa perf 0.8612568131325651
# ...
# abstfrac 0.3 distmaxclassprobfromone perf 0.778494012143921
# abstfrac 0.15 entropy perf 0.8570042112605822
# abstfrac 0.3 entropy perf 0.7762213978065414
# abstfrac 0.15 variance perf 0.8060488775555597
# abstfrac 0.3 variance perf 0.7285862870576785
#
# on fold 16
#
# yescalib base perf 0.806178912580685
# abstfrac 0.15 estmarginalweightedkappa perf 0.8736549197629284
# abstfrac 0.3 estmarginalweightedkappa perf 0.8938968768155423
# abstfrac 0.15 jsdiv perf 0.8419864243434596
# abstfrac 0.3 jsdiv perf 0.8522816778590284
# abstfrac 0.15 distmaxclassprobfromone perf 0.8301088386070157
# abstfrac 0.3 distmaxclassprobfromone perf 0.772086085910486
# abstfrac 0.15 entropy perf 0.8460853651947235
# abstfrac 0.3 entropy perf 0.7787824031457048
# abstfrac 0.15 variance perf 0.7827748900001235
# abstfrac 0.3 variance perf 0.7250023363926561
#
# nocalib base perf 0.806178912580685
# abstfrac 0.15 estmarginalweightedkappa perf 0.8714041488689778
# abstfrac 0.3 estmarginalweightedkappa perf 0.8993519707362206
# abstfrac 0.15 jsdiv perf 0.8442187609456032
# abstfrac 0.3 jsdiv perf 0.8566440269274374
# abstfrac 0.15 distmaxclassprobfromone perf 0.8246062714685812
# abstfrac 0.3 distmaxclassprobfromone perf 0.771380188966126
# abstfrac 0.15 entropy perf 0.8409163645247482
# abstfrac 0.3 entropy perf 0.7711363185365824
# abstfrac 0.15 variance perf 0.7911620811266533
# abstfrac 0.3 variance perf 0.7392428220326055
#
# on fold 17
#
# yescalib base perf 0.8071017138827303
# abstfrac 0.15 estmarginalweightedkappa perf 0.8791625707082371
# abstfrac 0.3 estmarginalweightedkappa perf 0.8975731160888197
# abstfrac 0.15 jsdiv perf 0.8370521840096217
# abstfrac 0.3 jsdiv perf 0.8489591962516485
# abstfrac 0.15 distmaxclassprobfromone perf 0.829605291327443
# abstfrac 0.3 distmaxclassprobfromone perf 0.7690041285396157
# abstfrac 0.15 entropy perf 0.8529368909902355
# abstfrac 0.3 entropy perf 0.7812237716145707
# abstfrac 0.15 variance perf 0.7801230459761415
# abstfrac 0.3 variance perf 0.6965391948396881
#
# nocalib base perf 0.8071017138827303
# abstfrac 0.15 estmarginalweightedkappa perf 0.87957059909433
# abstfrac 0.3 estmarginalweightedkappa perf 0.902109011382246
# abstfrac 0.15 jsdiv perf 0.843424726250798
# abstfrac 0.3 jsdiv perf 0.8546536999061989
# abstfrac 0.15 distmaxclassprobfromone perf 0.825167482499022
# abstfrac 0.3 distmaxclassprobfromone perf 0.7658050429130425
# abstfrac 0.15 entropy perf 0.8453589273619645
# abstfrac 0.3 entropy perf 0.7694363081376042
# abstfrac 0.15 variance perf 0.7873876383418087
# abstfrac 0.3 variance perf 0.7190340347716553
#
# on fold 18
#
# yescalib base perf 0.8081110293801426
# abstfrac 0.15 estmarginalweightedkappa perf 0.8723625047513859
# abstfrac 0.3 estmarginalweightedkappa perf 0.8944900181614434
# abstfrac 0.15 jsdiv perf 0.8405426530581732
# abstfrac 0.3 jsdiv perf 0.8578434814749527
# abstfrac 0.15 distmaxclassprobfromone perf 0.8098251118441814
# abstfrac 0.3 distmaxclassprobfromone perf 0.6772002238642794
# abstfrac 0.15 entropy perf 0.829842708263393
# abstfrac 0.3 entropy perf 0.6770697474142371
# abstfrac 0.15 variance perf 0.7445984913298012
# abstfrac 0.3 variance perf 0.593670351559743
#
# nocalib base perf 0.8081110293801426
# abstfrac 0.15 estmarginalweightedkappa perf 0.8701104109526661
# abstfrac 0.3 estmarginalweightedkappa perf 0.8974988441790789
# abstfrac 0.15 jsdiv perf 0.8425545280208974
# abstfrac 0.3 jsdiv perf 0.8616014032875341
# abstfrac 0.15 distmaxclassprobfromone perf 0.8041626085410046
# abstfrac 0.3 distmaxclassprobfromone perf 0.6753155975580605
# abstfrac 0.15 entropy perf 0.8238869705185652
# abstfrac 0.3 entropy perf 0.6776664511434882
# abstfrac 0.15 variance perf 0.7491192937633913
# abstfrac 0.3 variance perf 0.6140929179105916
#
# on fold 19
#
# yescalib base perf 0.8002847782931988
# abstfrac 0.15 estmarginalweightedkappa perf 0.8601886471689626
# abstfrac 0.3 estmarginalweightedkappa perf 0.8817355789787409
# abstfrac 0.15 jsdiv perf 0.8357184778551429
# abstfrac 0.3 jsdiv perf 0.8462860560503382
# abstfrac 0.15 distmaxclassprobfromone perf 0.801105328435057
# abstfrac 0.3 distmaxclassprobfromone perf 0.7018786582209329
# abstfrac 0.15 entropy perf 0.8255738297739175
# abstfrac 0.3 entropy perf 0.7165127691471371
# abstfrac 0.15 variance perf 0.7567190361176066
# abstfrac 0.3 variance perf 0.6314224105497661
#
# nocalib base perf 0.8002847782931988
# abstfrac 0.15 estmarginalweightedkappa perf 0.8576478279679471
# abstfrac 0.3 estmarginalweightedkappa perf 0.8869018758542309
# abstfrac 0.15 jsdiv perf 0.8376729795686981
# abstfrac 0.3 jsdiv perf 0.8477038720905138
# abstfrac 0.15 distmaxclassprobfromone perf 0.7969874743893932
# abstfrac 0.3 distmaxclassprobfromone perf 0.7053240423357192
# abstfrac 0.15 entropy perf 0.8177209441370354
# abstfrac 0.3 entropy perf 0.7058313566017087
# abstfrac 0.15 variance perf 0.7584687505182617
# abstfrac 0.3 variance perf 0.6556002021891696
#
# on fold 20
#
# yescalib base perf 0.8077896024256765
# abstfrac 0.15 estmarginalweightedkappa perf 0.8704987641292021
# abstfrac 0.3 estmarginalweightedkappa perf 0.8907942780367594
# abstfrac 0.15 jsdiv perf 0.8413859153665499
# abstfrac 0.3 jsdiv perf 0.8550460178412613
# abstfrac 0.15 distmaxclassprobfromone perf 0.8163155486945096
# abstfrac 0.3 distmaxclassprobfromone perf 0.7460978861685368
# abstfrac 0.15 entropy perf 0.8345080105159433
# abstfrac 0.3 entropy perf 0.7469707416101055
# abstfrac 0.15 variance perf 0.7675278361857546
# abstfrac 0.3 variance perf 0.6926088826100303
#
# nocalib base perf 0.8077896024256765
# abstfrac 0.15 estmarginalweightedkappa perf 0.8703648408061331
# abstfrac 0.3 estmarginalweightedkappa perf 0.89460046610641
# abstfrac 0.15 jsdiv perf 0.8441687240718008
# abstfrac 0.3 jsdiv perf 0.8585494454595057
# abstfrac 0.15 distmaxclassprobfromone perf 0.8106833605240235
# abstfrac 0.3 distmaxclassprobfromone perf 0.7437683387379395
# abstfrac 0.15 entropy perf 0.8285282262762034
# abstfrac 0.3 entropy perf 0.7442423142907213
# abstfrac 0.15 variance perf 0.7736930975802997
# abstfrac 0.3 variance perf 0.6942628544760372
#
# on fold 21
#
# yescalib base perf 0.8323830255125058
# abstfrac 0.15 estmarginalweightedkappa perf 0.8824754504535499
# abstfrac 0.3 estmarginalweightedkappa perf 0.8985956067122001
# abstfrac 0.15 jsdiv perf 0.8563367634418331
# abstfrac 0.3 jsdiv perf 0.8638943119146012
# abstfrac 0.15 distmaxclassprobfromone perf 0.8493152938352494
# abstfrac 0.3 distmaxclassprobfromone perf 0.7767184913402227
# abstfrac 0.15 entropy perf 0.8609513274316714
# abstfrac 0.3 entropy perf 0.7804464194101546
# abstfrac 0.15 variance perf 0.7964077821381195
# abstfrac 0.3 variance perf 0.6866714441672961
#
# nocalib base perf 0.8323830255125058
# abstfrac 0.15 estmarginalweightedkappa perf 0.8825779700026883
# abstfrac 0.3 estmarginalweightedkappa perf 0.903407035734678
# abstfrac 0.15 jsdiv perf 0.8599380846986037
# abstfrac 0.3 jsdiv perf 0.867899927401861
# abstfrac 0.15 distmaxclassprobfromone perf 0.845341780813212
# abstfrac 0.3 distmaxclassprobfromone perf 0.7785499213233937
# abstfrac 0.15 entropy perf 0.8570821629058205
# abstfrac 0.3 entropy perf 0.7764551249098883
# abstfrac 0.15 variance perf 0.8047881494071905
# abstfrac 0.3 variance perf 0.7162409292785925
#
# on fold 22
#
# yescalib base perf 0.8186803740664235
# abstfrac 0.15 estmarginalweightedkappa perf 0.8824013004705136
# abstfrac 0.3 estmarginalweightedkappa perf 0.9000838068678296
# abstfrac 0.15 jsdiv perf 0.8446786296337339
# abstfrac 0.3 jsdiv perf 0.8559131920586505
# abstfrac 0.15 distmaxclassprobfromone perf 0.8405276677571203
# abstfrac 0.3 distmaxclassprobfromone perf 0.7849217638691323
# abstfrac 0.15 entropy perf 0.859139554662421
# abstfrac 0.3 entropy perf 0.791229161544373
# abstfrac 0.15 variance perf 0.7997645407081329
# abstfrac 0.3 variance perf 0.7359947702054671
#
# nocalib base perf 0.8186803740664235
# abstfrac 0.15 estmarginalweightedkappa perf 0.8833506520050896
# abstfrac 0.3 estmarginalweightedkappa perf 0.9048421925694489
# abstfrac 0.15 jsdiv perf 0.8489449662768971
# abstfrac 0.3 jsdiv perf 0.8609543512601646
# abstfrac 0.15 distmaxclassprobfromone perf 0.8364859052746179
# abstfrac 0.3 distmaxclassprobfromone perf 0.7868459072585385
# abstfrac 0.15 entropy perf 0.8523110085683668
# abstfrac 0.3 entropy perf 0.7859639705192049
# abstfrac 0.15 variance perf 0.8070291405511384
# abstfrac 0.3 variance perf 0.7444223977322731
#
# on fold 23
#
# yescalib base perf 0.8146687162636606
# abstfrac 0.15 estmarginalweightedkappa perf 0.8759980731115086
# abstfrac 0.3 estmarginalweightedkappa perf 0.8908005255104816
# abstfrac 0.15 jsdiv perf 0.843673402241534
# abstfrac 0.3 jsdiv perf 0.8501379749021856
# abstfrac 0.15 distmaxclassprobfromone perf 0.829387093087592
# abstfrac 0.3 distmaxclassprobfromone perf 0.7545786006488874
# abstfrac 0.15 entropy perf 0.8505373036162086
# abstfrac 0.3 entropy perf 0.7551081270588775
# abstfrac 0.15 variance perf 0.7848703899913754
# abstfrac 0.3 variance perf 0.6990705158159745
#
# nocalib base perf 0.8146687162636606
# abstfrac 0.15 estmarginalweightedkappa perf 0.8757249301242884
# abstfrac 0.3 estmarginalweightedkappa perf 0.8937707842385489
# abstfrac 0.15 jsdiv perf 0.8472735140222826
# abstfrac 0.3 jsdiv perf 0.8531608124650801
# abstfrac 0.15 distmaxclassprobfromone perf 0.8227710758279788
# abstfrac 0.3 distmaxclassprobfromone perf 0.7555962312196502
# abstfrac 0.15 entropy perf 0.8426551556245017
# abstfrac 0.3 entropy perf 0.7540502984167899
# abstfrac 0.15 variance perf 0.7856823758078135
# abstfrac 0.3 variance perf 0.7158591635098821
#
# on fold 24
#
# yescalib base perf 0.819021193941565
# abstfrac 0.15 estmarginalweightedkappa perf 0.8770536730887297
# abstfrac 0.3 estmarginalweightedkappa perf 0.8963785371162447
# abstfrac 0.15 jsdiv perf 0.8462509532699727
# abstfrac 0.3 jsdiv perf 0.8594936353373841
# abstfrac 0.15 distmaxclassprobfromone perf 0.8381405594701837
# abstfrac 0.3 distmaxclassprobfromone perf 0.7699963144568294
# abstfrac 0.15 entropy perf 0.8590660010173379
# abstfrac 0.3 entropy perf 0.786181911014615
# abstfrac 0.15 variance perf 0.7827150236215387
# abstfrac 0.3 variance perf 0.695419427354718
#
# nocalib base perf 0.819021193941565
# abstfrac 0.15 estmarginalweightedkappa perf 0.878959109398767
# abstfrac 0.3 estmarginalweightedkappa perf 0.9029279232819662
# abstfrac 0.15 jsdiv perf 0.8520810000150439
# abstfrac 0.3 jsdiv perf 0.8636118788116304
# abstfrac 0.15 distmaxclassprobfromone perf 0.8332844185008726
# abstfrac 0.3 distmaxclassprobfromone perf 0.7711771877373297
# abstfrac 0.15 entropy perf 0.8523639525676754
# abstfrac 0.3 entropy perf 0.7695379486098238
# abstfrac 0.15 variance perf 0.7897956197765288
# abstfrac 0.3 variance perf 0.7280982202424462
#
# on fold 25
#
# yescalib base perf 0.8163231456114086
# abstfrac 0.15 estmarginalweightedkappa perf 0.8720295178441471
# abstfrac 0.3 estmarginalweightedkappa perf 0.8904360467725257
# abstfrac 0.15 jsdiv perf 0.8394480339775556
# abstfrac 0.3 jsdiv perf 0.8498039542255935
# abstfrac 0.15 distmaxclassprobfromone perf 0.8291945974763213
# abstfrac 0.3 distmaxclassprobfromone perf 0.7180572815746558
# abstfrac 0.15 entropy perf 0.8488535697620673
# abstfrac 0.3 entropy perf 0.7238253792762901
# abstfrac 0.15 variance perf 0.7891260765298697
# abstfrac 0.3 variance perf 0.6511393577005881
#
# nocalib base perf 0.8163231456114086
# abstfrac 0.15 estmarginalweightedkappa perf 0.8757775465646668
# abstfrac 0.3 estmarginalweightedkappa perf 0.8948527589178237
# abstfrac 0.15 jsdiv perf 0.8451639528732261
# abstfrac 0.3 jsdiv perf 0.8540706962043523
# abstfrac 0.15 distmaxclassprobfromone perf 0.8253894309172783
# abstfrac 0.3 distmaxclassprobfromone perf 0.7222653236055528
# abstfrac 0.15 entropy perf 0.842893347910779
# abstfrac 0.3 entropy perf 0.7163559161706186
# abstfrac 0.15 variance perf 0.7955964961124782
# abstfrac 0.3 variance perf 0.6624829557979448
#
# on fold 26
#
# yescalib base perf 0.796348745069026
# abstfrac 0.15 estmarginalweightedkappa perf 0.8646728419341422
# abstfrac 0.3 estmarginalweightedkappa perf 0.8882952726128269
# abstfrac 0.15 jsdiv perf 0.8344256662318417
# abstfrac 0.3 jsdiv perf 0.8476601046878304
# abstfrac 0.15 distmaxclassprobfromone perf 0.8053342110337706
# abstfrac 0.3 distmaxclassprobfromone perf 0.7380723790558339
# abstfrac 0.15 entropy perf 0.828755771037393
# abstfrac 0.3 entropy perf 0.7371295102552053
# abstfrac 0.15 variance perf 0.7610347327756204
# abstfrac 0.3 variance perf 0.6827554410099963
#
# nocalib base perf 0.796348745069026
# abstfrac 0.15 estmarginalweightedkappa perf 0.8627136765228143
# abstfrac 0.3 estmarginalweightedkappa perf 0.8916634618892303
# abstfrac 0.15 jsdiv perf 0.8383657410150055
# abstfrac 0.3 jsdiv perf 0.8513582394241408
# abstfrac 0.15 distmaxclassprobfromone perf 0.8009188488728846
# abstfrac 0.3 distmaxclassprobfromone perf 0.7415601802377516
# abstfrac 0.15 entropy perf 0.8231512177674374
# abstfrac 0.3 entropy perf 0.736480181330606
# abstfrac 0.15 variance perf 0.764359800919935
# abstfrac 0.3 variance perf 0.6988762857312731
#
# on fold 27
#
# yescalib base perf 0.8070087380831215
# abstfrac 0.15 estmarginalweightedkappa perf 0.8702333656685752
# abstfrac 0.3 estmarginalweightedkappa perf 0.8935614965263984
# abstfrac 0.15 jsdiv perf 0.8421229350641194
# abstfrac 0.3 jsdiv perf 0.8545295302027665
# abstfrac 0.15 distmaxclassprobfromone perf 0.8145420196389557
# abstfrac 0.3 distmaxclassprobfromone perf 0.7260776083878734
# abstfrac 0.15 entropy perf 0.8358767253033701
# abstfrac 0.3 entropy perf 0.7373181088264562
# abstfrac 0.15 variance perf 0.7827723240709313
# abstfrac 0.3 variance perf 0.680538527110931
#
# nocalib base perf 0.8070087380831215
# abstfrac 0.15 estmarginalweightedkappa perf 0.8693837101333991
# abstfrac 0.3 estmarginalweightedkappa perf 0.8965232625293277
# abstfrac 0.15 jsdiv perf 0.8452607406479526
# abstfrac 0.3 jsdiv perf 0.8588056147857235
# abstfrac 0.15 distmaxclassprobfromone perf 0.8081233276607683
# abstfrac 0.3 distmaxclassprobfromone perf 0.7231985401067031
# abstfrac 0.15 entropy perf 0.8298539120629513
# abstfrac 0.3 entropy perf 0.7266115509862392
# abstfrac 0.15 variance perf 0.7804086316534036
# abstfrac 0.3 variance perf 0.6931648536440314
#
# on fold 28
#
# yescalib base perf 0.8117059945356229
# abstfrac 0.15 estmarginalweightedkappa perf 0.8744448878201376
# abstfrac 0.3 estmarginalweightedkappa perf 0.8948212584891733
# abstfrac 0.15 jsdiv perf 0.8444590526314937
# abstfrac 0.3 jsdiv perf 0.8600468296942768
# abstfrac 0.15 distmaxclassprobfromone perf 0.8187931798337009
# abstfrac 0.3 distmaxclassprobfromone perf 0.7177492316849801
# abstfrac 0.15 entropy perf 0.8330227352629955
# abstfrac 0.3 entropy perf 0.7259751568045811
# abstfrac 0.15 variance perf 0.7662850270979025
# abstfrac 0.3 variance perf 0.6512159018334933
#
# nocalib base perf 0.8117059945356229
# abstfrac 0.15 estmarginalweightedkappa perf 0.873872465188928
# abstfrac 0.3 estmarginalweightedkappa perf 0.8973559635742421
# abstfrac 0.15 jsdiv perf 0.8476105728042433
# abstfrac 0.3 jsdiv perf 0.8632174400107667
# abstfrac 0.15 distmaxclassprobfromone perf 0.814808162878241
# abstfrac 0.3 distmaxclassprobfromone perf 0.7220096635716224
# abstfrac 0.15 entropy perf 0.8290856863748274
# abstfrac 0.3 entropy perf 0.7162506069953709
# abstfrac 0.15 variance perf 0.7759954872637111
# abstfrac 0.3 variance perf 0.6574831526006527
#
# on fold 29
#
# yescalib base perf 0.8246185939035392
# abstfrac 0.15 estmarginalweightedkappa perf 0.8831003466464347
# abstfrac 0.3 estmarginalweightedkappa perf 0.9052302064262313
# abstfrac 0.15 jsdiv perf 0.8621557529263044
# abstfrac 0.3 jsdiv perf 0.8763755816532469
# abstfrac 0.15 distmaxclassprobfromone perf 0.8279224825567894
# abstfrac 0.3 distmaxclassprobfromone perf 0.7280968651719266
# abstfrac 0.15 entropy perf 0.8419187257065035
# abstfrac 0.3 entropy perf 0.7347976411604069
# abstfrac 0.15 variance perf 0.7760448886062052
# abstfrac 0.3 variance perf 0.6482529302997357
#
# nocalib base perf 0.8246185939035392
# abstfrac 0.15 estmarginalweightedkappa perf 0.8823614151407069
# abstfrac 0.3 estmarginalweightedkappa perf 0.9065277495743451
# abstfrac 0.15 jsdiv perf 0.8652933251440316
# abstfrac 0.3 jsdiv perf 0.8791754039093265
# abstfrac 0.15 distmaxclassprobfromone perf 0.8236662143513376
# abstfrac 0.3 distmaxclassprobfromone perf 0.729066424835822
# abstfrac 0.15 entropy perf 0.8363251030789367
# abstfrac 0.3 entropy perf 0.7282862663659049
# abstfrac 0.15 variance perf 0.7796694800145576
# abstfrac 0.3 variance perf 0.6497038672946136
